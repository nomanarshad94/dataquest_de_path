# %% [markdown]
# ## Introducing Wikipedia Data

# %%
import os

os.listdir("wiki")
# Out:
# ['Furubira_District,_Hokkaido.html',
#  'Valentin_Yanin.html',
#  'Kings_XI_Punjab_in_2014.html',
#  'William_Harvey_Lillard.html',
#  'Radial_Road_3.html',
#  'George_Weldrick.html',
#  'Zgornji_Otok.html',
#  'Blue_Heelers_(season_8).html',
#  'Taggen_Nunatak.html',
#  '1951_National_League_tie-breaker_series.html',
#  'List_of_number-one_singles_of_1993_(Finland).html',
#  'Vrila.html',
#  'William_Henry_Porter.html',
#  'Clive_Brown_(footballer).html',
#  '2010_Karshi_Challenger_%E2%80%93_Singles.html',
#  'Blick_nach_Rechts.html',
#  'Central_District_(Rezvanshahr_County).html',
#  'Gal%C3%A1pagos,_Guadalajara.html',
#  'Campus_of_Texas_A%26M_University.html',
#  'Alexios_Aspietes.html',
#  'Mei_Lanfang.html',
#  'Thalkirchen-Obersendling-Forstenried-F%C3%BCrstenried-Solln.html',
#  'Coalville_Town_railway_station.html',
#  'Gennady_Lesun.html',
#  'Bartrum_Glacier.html',
#  'Victor_S._Mamatey.html',
#  'Gottfried_Keller.html',
#  'Table_Point_Formation.html',
#  'Nobuhiko_Ushiba.html',
#  'Master_of_Space_and_Time.html',
#  'Early_medieval_states_in_Kazakhstan.html',
#  'Eressa_aperiens.html',
#  'Companys,_proc%C3%A9s_a_Catalunya.html',
#  'Myrtle_(sternwheeler).html',
#  'Abanycha_bicolor.html',
#  'Aubrey_Fair.html',
#  'Urban_chicken.html',
#  'Elgin_National_Watch_Company.html',
#  'Goran_Obradovi%C4%87_(footballer,_born_1976).html',
#  'Bluesin%27_Around.html',
#  'Pr%C3%A9liminaires.html',
#  'Antae_temple.html',
#  'Metis_Institute_of_Polytechnic.html',
#  '1953%E2%80%9354_FA_Cup_qualifying_rounds.html',
#  'Sverre_Solberg.html',
#  'John_Reid_(British_Army_officer).html',
#  'List_of_mountains_of_the_Falkland_Islands.html',
#  'Fischli.html',
#  'Aylon_Darwin_Tavella.html',
#  'Sambhaji_Raje_Chhatrapati.html',
#  'Alexander_Rizzoni.html',
#  'Pixley_Township,_Clay_County,_Illinois.html',
#  'Jules_Verne_ATV.html',
#  'Tomohiko_It%C5%8D_(director).html',
#  'Battle_of_Isonzo_(489).html',
#  'Pictogram.html',
#  'Alan_Oakley.html',
#  'Le_Premier_Sexe.html',
#  'Eugamandus_brunneus.html',
#  'Arthur_Norman.html',
#  'Feel_No_Fret.html',
#  'Claire_Danes.html',
#  'Adish_Aggarwala.html',
#  'Egg_coffee.html',
#  'Diplacus_aurantiacus.html',
#  'Sumba%E2%80%93Flores_languages.html',
#  'Justus_Ferdinand_Poggenburg_II.html',
#  'Svendborg_Skibsv%C3%A6rft.html',
#  'Communities_of_Tulu_Nadu.html',
#  'Supermoon.html',
#  'Ron_Harvey_(rugby_union).html',
#  'Olivaceous_flatbill.html',
#  'Javier_Bruses.html',
#  'Mitrella_guerreiroi.html',
#  'Louis_Vivet.html',
#  'Yarkant_County.html',
#  'Mrs._Wilkes%27_Dining_Room.html',
#  'Theonellamide_F.html',
#  'PTPRS.html',
#  'Legge.html',
#  'Constance_D%27Arcy_Mackay.html',
#  'Tom_Buffington.html',
#  'Leuke_Kome.html',
#  'Horace_Pinker.html',
#  'C%27est_la_vie_(Khaled_song).html',
#  'Kelvin_R._Throop.html',
#  'Yemeni_rial.html',
#  'Miss_Guatemala_2008.html',
#  'Merwin_Hodel.html',
#  'A_Beautiful_Valley.html',
#  'H._T._Hackney_Company.html',
#  'Berzeliustinden.html',
#  'John_Nelson_(merchant).html',
#  'Short_Message_service_center.html',
#  'Lebanon_at_the_1980_Winter_Olympics.html',
#  'Streatfeild_family.html',
#  'Kendal_Williams.html',
#  'List_of_women%27s_football_clubs_in_Japan.html',
#  'Tam%C3%A1s_Buday.html',
#  'Jeff_Weise.html',
#  'William_Harper_(South_Carolina).html',
#  '2007%E2%80%9308_Huddersfield_Town_A.F.C._season.html',
#  'Shanghai_Shuffle.html',
#  'Danny_Gray.html',
#  'Platinum_fulminate.html',
#  'Guyana_at_the_2010_Central_American_and_Caribbean_Games.html',
#  'Alpine_skiing_at_the_1994_Winter_Olympics_%E2%80%93_Men%27s_combined.html',
#  'Jeecy-Vea.html',
#  'The_Wire_(JTF-GTMO).html',
#  'Turowo,_Pomeranian_Voivodeship.html',
#  'Mike_Purdy.html',
#  'Hagen_Hauptbahnhof.html',
#  'Patrick_F._Philbin.html',
#  'Ribboned_sweetlips.html',
#  'Endre_Church.html',
#  'Nabil_Baha.html',
#  'Mudramothiram.html',
#  'Schlettau.html',
#  'Ameenapuram.html',
#  'Nathaniel_Merriman.html',
#  '2011_ITU_Duathlon_World_Championships.html',
#  'Mara_Keisling.html',
#  'Ragnar_Gustavsson.html',
#  'William_de_Pembroke.html',
#  'Teskey,_Kyrgyzstan.html',
#  'Mark_Maunder.html',
#  'Wheatland_High_School_(California).html',
#  'Markus_Blutsch.html',
#  'Kristiene_Gong.html',
#  'Punjab_War.html',
#  'Syncretocarpus.html',
#  'Gordon_Bau.html',
#  'Bibliography_of_Niue.html',
#  'Marv_Felderman.html',
#  'Code_page_1023.html',
#  'Discretionary_trust.html',
#  'Cryptographic_primitive.html',
#  'Alex_Kurtzman.html',
#  'William_Samuel_Viner.html',
#  'Nyck_de_Vries.html',
#  'Liga_de_F%C3%BAtbol_Profesional_Boliviano.html',
#  'Scott_McPherson.html',
#  'Kirsten_Klein.html',
#  '2011%E2%80%9312_Western_Collegiate_Hockey_Association_women%27s_ice_hockey_season.html',
#  'List_of_lakes_in_Independence_County,_Arkansas.html',
#  'David_Sands_(psychologist).html',
#  'Beyond_Magnetic.html',
#  'Church_of_the_SubGenius.html',
#  'Vaccinium_padifolium.html',
#  'ZNF644.html',
#  '2005%E2%80%9306_in_Welsh_football.html',
#  'Regina_Pacis_Catholic_Secondary_School.html',
#  'Filip_Pyrochta.html',
#  'Bal%C3%A1zs_Vill%C3%A1m.html',
#  'Gorgopis_subrimosa.html',
#  'Harry_Lynde_Bradley.html',
#  'North_Otago_Astronomical_Society_Observatory.html',
#  'Morgana_King.html',
#  'Don_Parsons_(ice_hockey).html',
#  'Evene.html',
#  'Therese_Maron.html',
#  'Plasnewydd.html',
#  'Belvedere,_London.html',
#  '1958_Wightman_Cup.html',
#  'Bias.html',
#  'Terry_Cox.html',
#  'Heo_Mok.html',
#  'Maple_Jam_Music_Group.html',
#  'Heiko_M%C3%A4rz.html',
#  'Imperial_Venus_(film).html',
#  'Charles_Stuart_(rugby_union).html',
#  'Yarumal.html',
#  'Olive_Dennis.html',
#  'Italy%E2%80%93United_States_relations.html',
#  'Camp_Nelson_Confederate_Cemetery.html',
#  'Treaty_of_Warsaw_(1970).html',
#  'Bill_Widenhouse.html',
#  'Benny_Lee.html',
#  '1898_Colgate_football_team.html',
#  'Caprinia_versicolor.html',
#  'P%C5%82az%C3%B3wka.html',
#  'MoneyHunt.html',
#  'Neville_Hewitt_(American_football).html',
#  'Faces_(Run%E2%80%93D.M.C._song).html',
#  'Dialogue_for_Hungary.html',
#  'Wu_Jin.html',
#  'Kul_Gul.html',
#  'Igor_and_Grichka_Bogdanoff.html',
#  'Tapat%C3%ADo_hot_sauce.html',
#  'Two_House_theology.html',
#  'Tramery.html',
#  'Revolutionary_Vol._1.html',
#  'Gaston_Lane.html',
#  'MobiasBanca.html',
#  'Lectionary_69.html',
#  'Arvind_Gokhale.html',
#  'Thomas_Croci.html',
#  'T%C5%8Dr%C5%8D_nagashi.html',
#  'Medicago_murex.html',
#  'Red-eyed_dove.html',
#  'Jazz_at_the_Plaza_Vol._II.html',
#  'Josef_Mik.html',
#  'AVM_GmbH.html',
#  '2001_Australian_Individual_Speedway_Championship.html',
#  'Mariana_Mazzucato.html',
#  'United_Nations_Security_Council_Resolution_731.html',
#  'Oldfield_Baby_Great_Lakes.html',
#  'Redwater,_Mississippi.html',
#  'Wangerooge-class_tug.html',
#  'Achaea_faber.html',
#  'Ramana,_Pakistan.html',
#  'Charles_Page_(cricketer).html',
#  'Sweeper.html',
#  'Canbelego_County.html',
#  'Wilson_Global_Explorer.html',
#  'Craig_Chester.html',
#  'Derek_Acorah.html',
#  'Wilbraham_%26_Monson_Academy.html',
#  'Mountune_Racing.html',
#  'AB_v_CD.html',
#  'Jack_Goes_Home.html',
#  '2016_Minnesota_Vikings_season.html',
#  'Morning_Glory_(2010_film).html',
#  'Flashmob_(album).html',
#  'I_Marine_Expeditionary_Force.html',
#  'KDDQ.html',
#  'Tim_Spencer_(singer).html',
#  'Suri,_Kerman.html',
#  'Seeking_Gaddafi.html',
#  'Jotedar.html',
#  'Kyokutou_I_Love_You.html',
#  'The_Portal_(community_center).html',
#  'John_C._Freeman_Weather_Museum.html',
#  'Curtiss-Wright_Hangar_(Columbia,_South_Carolina).html',
#  'S%C3%BCderelbe.html',
#  'Mick_Crotty.html',
#  'Juan_Carlos_Pinz%C3%B3n.html',
#  'Now_That%27s_What_I_Call_Music!_55_(U.S._series).html',
#  'Johnny_Morris_(American_football).html',
#  'Lower_Blackburn_Grade_Bridge.html',
#  'Van_Buren,_Ohio.html',
#  'Rules_of_Engagement_(Alexander_novel).html',
#  'The_Wedding_(Sparks_novel).html',
#  'West_Valley,_Washington.html',
#  '2017_Orange_County_Breakers_season.html',
#  'Fureai_kippu.html',
#  'Margo_Reuten.html',
#  'Saladino%27s_Inc.html',
#  'The_Master_Plan_(album).html',
#  'Mark_Baker_(basketball).html',
#  'Zehut.html',
#  'Sol_Eclipse.html',
#  'Para%C3%B1aque_National_High_School,_Don_Galo_Annex.html',
#  '2004_Tuvalu_A-Division.html',
#  'Jonathan_A._Goldstein.html',
#  'Naoise_%C3%93_Muir%C3%AD.html',
#  'F%C3%A9lix_C%C3%A1rdenas.html',
#  '83_(number).html',
#  'SBOA_School_%26_Junior_College.html',
#  'Devil_on_Horseback.html',
#  'Siuniu.html',
#  'Devarampally.html',
#  'SolydXK.html',
#  'Intel_QuickPath_Interconnect.html',
#  'Sierra_Leone_Studies.html',
#  'Harry_Hill_Bandholtz.html',
#  'Bijou,_California.html',
#  'Abdelwahid_Aboud_Mackaye.html',
#  'Equestrian_at_the_1936_Summer_Olympics.html',
#  'Pergamus.html',
#  'Biorock.html',
#  '2016%E2%80%9317_New_Zealand_Football_Championship.html',
#  'Antigonadotropin.html',
#  'Salem-Auburn_Streets_Historic_District.html',
#  'Henrique_da_Silveira.html',
#  'Jane_Wrightson.html',
#  'Gregory_Fortuin.html',
#  'Prisons_in_Bolivia.html',
#  'Ga%C5%A1parci.html',
#  'Paul_Maddrell.html',
#  'Vivian_Prokop.html',
#  'Oued_Tl%C3%A9lat.html',
#  'Paser_Crossword_Stela.html',
#  'Shpolskii_matrix.html',
#  'Bruce_Conte.html',
#  'Old_Mill_Creek,_Illinois.html',
#  'SC_Goldau.html',
#  'Robert_Frederick_Blum.html',
#  'Meydan-e_Jahad_Metro_Station.html',
#  'Sagrai.html',
#  'Falman-County_Acres,_Texas.html',
#  'Sa_Re_Ga_Ma_Pa_Challenge_USA_2008.html',
#  'La_Franja.html',
#  'Estadio_Municipal_Pozoblanco.html',
#  'Unionidae.html',
#  'Corporation_(university).html',
#  '1910_in_literature.html',
#  'Robert_Boehringer.html',
#  'Social_impact_of_YouTube.html',
#  'FC_Khikhani_Khulo.html',
#  'Cobble_Hill,_Brooklyn.html',
#  'The_Lavender_Cowboy.html',
#  'Coup_d%27%C3%A9tat.html',
#  'Tomislav_Erceg.html',
#  'USS_Parris_Island_(AG-72).html',
#  'Meir_Zlotowitz.html',
#  'Awali.html',
#  'Gacharageini.html',
#  'Fortuna_Glacier.html',
#  'Dragnet_(franchise).html',
#  'Winters-Wimberley_House.html',
#  'Ban_On.html',
#  '1915_Montana_football_team.html',
#  'Vijay_Govindarajan.html',
#  'Aiva.html',
#  '2011_Wainwright_Roaming_Buffalo_Classic.html',
#  'Uralochka_Zlatoust.html',
#  'Sybra_preapicemaculata.html',
#  'Papyrus_Oxyrhynchus_56.html',
#  'Promises,_Promises_(Incubus_song).html',
#  'Josh_West.html',
#  'Second_Valley,_South_Australia.html',
#  'Doug_Sahm_and_Band.html',
#  'Hope_7_(album).html',
#  'Mohamed_El-Sayed.html',
#  'Qalat_Kat.html',
#  'Woodward_Dream_Cruise.html',
#  'USS_Goldcrest.html',
#  '2016%E2%80%9317_Little_Rock_Trojans_women%27s_basketball_team.html',
#  'Aniavan.html',
#  'Instrumental.html',
#  'Christopher_Speer.html',
#  'Maniitsoq_structure.html',
#  'Minardi_M185.html',
#  'Millennium_Art_Academy.html',
#  'Australian_Musician_(magazine).html',
#  'Charlton_baronets.html',
#  'Cheddar_Ales.html',
#  'Dewoitine_D.21.html',
#  'List_of_Bellator_MMA_events.html',
#  'Tubular_Bells_II.html',
#  'Touch_FM_(Coventry).html',
#  'Kadamaha.html',
#  'James_L._Hull.html',
#  'Furto_di_sera_bel_colpo_si_spera.html',
#  'Hayes_Township,_Clay_County,_Kansas.html',
#  'Pontefract_by-election,_1941.html',
#  'Meleh_Kabud-e_Sofla.html',
#  'Symeon_Stylites_of_Lesbos.html',
#  'Kellie_Jones.html',
#  'Dominique_Voynet.html',
#  'Mohammad_Reza_Niknahal.html',
#  'Garden-based_learning.html',
#  'Sir_Run_Run_Shaw_Hospital.html',
#  'List_of_Argentine_Primera_Divisi%C3%B3n_transfers_January_2011.html',
#  'Gaetanus_Matthew_Perez.html',
#  'Sudanese_pound.html',
#  'Exploratorium_(film).html',
#  'Foulonia.html',
#  'Reb_Russell.html',
#  'Miltochrista_fuscozonata.html',
#  'Luvvie_Darling.html',
#  'Amborella.html',
#  'List_of_Bratz_episodes.html',
#  'Udi,_Enugu.html',
#  'Canyamars.html',
#  'Kenny_Cordray.html',
#  'Siege_of_Valenciennes_(1793).html',
#  'Santa_Mar%C3%ADa_Yaves%C3%ADa.html',
#  'Baddiewinkle.html',
#  'Chemin_d%27Aylmer.html',
#  'SSR-180,711.html',
#  'David_Solomona.html',
#  'Rally_for_Democracy_and_Progress_(Benin).html',
#  'I_Am_Cold.html',
#  'Sarah_Blakley-Cartwright.html',
#  'Rubber_Biscuit.html',
#  'Heald_Green.html',
#  'Charles_Smith_Wilcox.html',
#  'Swathi_Chinukulu.html',
#  'Noise_(song).html',
#  'Maukala.html',
#  'Hilyard_Robinson.html',
#  'Shellie_Morris.html',
#  'Bob_Bass.html',
#  'Diphilus_(physician).html',
#  'Arun_K._Pati.html',
#  'Agaritine_gamma-glutamyltransferase.html',
#  'Sky_Regional_Airlines.html',
#  'Wilhelm_August_Graah.html',
#  'Avenira.html',
#  'Slade_School_of_Fine_Art.html',
#  'Zane_Radcliffe.html',
#  'Devitt_Insurance.html',
#  'Lincoln_Clarkes.html',
#  'Panhandle%E2%80%93Plains_Historical_Museum.html',
#  'Bahmanabad-e_Olya.html',
#  'Tarsila_do_Amaral.html',
#  'Ioana_Badea.html',
#  'The_Gentleman_Without_a_Residence_(1915_film).html',
#  'Troso_da_Monza.html',
#  'Walter_of_Durham.html',
#  'James_Wilkes_Maurice.html',
#  'Section_20_of_the_Canadian_Charter_of_Rights_and_Freedoms.html',
#  'Ferdinand_Mainzer.html',
#  'Keeled_sideband.html',
#  'Palio_zosterae.html',
#  'Lydia_Villa-Komaroff.html',
#  'Henri_Braqueni%C3%A9.html',
#  'Nickel(II)_hydroxide.html',
#  'Usher_Gahagan.html',
#  'John_V._G._Posey_House.html',
#  'Kfarhata.html',
#  'James_Alexander_Ulio.html',
#  'De_La_Salle_University_%E2%80%93_Dasmari%C3%B1as.html',
#  'When_You_Loved_Me.html',
#  'Flat_roof.html',
#  'Jack_Wong.html',
#  'The_Love-Girl_and_the_Innocent.html',
#  'Manhattan_Murder_Mystery.html',
#  'DiGiorgio_Corporation.html',
#  'Eugenio_Morelli.html',
#  'Kenneth_Thomas_(cricketer).html',
#  'Mar%C3%ADa_Calder%C3%B3n.html',
#  'James_Magee.html',
#  'Bill_Price_(baseball).html',
#  'Mount_Jim_Crow_National_Park.html',
#  'Avengers_Academy.html',
#  'Scrobipalpa_halophila.html',
#  'Swan_neck_deformity.html',
#  'Chhatrasal.html',
#  'Raymond_II,_Count_of_Toulouse.html',
#  'Macroglossum_pseudoluteata.html',
#  'Antibiotic_use_in_livestock.html',
#  'Omaha_Racers.html',
#  'Syngenor.html',
#  'Mecklenburg_Switzerland_and_Lake_Kummerow_Nature_Park.html',
#  'List_of_largest_chemical_producers.html',
#  'X-Cops_(band).html',
#  'Hannover_Indians.html',
#  'Carlos_Martins_(musician).html',
#  'Women%27s_javelin_throw_world_record_progression.html',
#  'Asparuh_Peak.html',
#  'Robert_K._Zukowski.html',
#  'Gorfion.html',
#  'Marson.html',
#  'I%27ve_Heard_That_Song_Before.html',
#  'Jens_Pauli_Skaalum.html',
#  'Chestnut_pie.html',
#  'Vitaly_Bianki.html',
#  'Coronium_(gastropod).html',
#  'Arnold_Freiherr_von_Biegeleben.html',
#  'Acacia_dermatophylla.html',
#  'Lis_L%C3%B8wert.html',
#  'Typhoon_Hester_(1952).html',
#  'Ugo_Okoye.html',
#  '2014%E2%80%9315_Kansas_State_Wildcats_men%27s_basketball_team.html',
#  'Kokan_Colony.html',
#  'Oleg_Novitskiy.html',
#  'Llwyn-Cus.html',
#  'Wilhelm_Wagenfeld_House.html',
#  'Erigeron_canaani.html',
#  'Eternamente_Romanticos.html',
#  'Lecithocera_sextacta.html',
#  'Arthur_Lelyveld.html',
#  'Bonny_River.html',
#  'Charles_Sears.html',
#  'Ingrid_Guimar%C3%A3es.html',
#  'Jonas_Ar%C4%8Dikauskas.html',
#  'Tonga_national_basketball_team.html',
#  'City_of_Mandaluyong_Science_High_School.html',
#  'Oktyabrsky_District,_Russia.html',
#  'Archibald_Gordon_(British_Army_officer).html',
#  'Kusaka_Station.html',
#  'Plze%C5%88_Zoo.html',
#  'WLSR.html',
#  'Friendship,_Wake_County,_North_Carolina.html',
#  'Wolfgang_Lutz.html',
#  'Curridge.html',
#  'Kendalia,_Texas.html',
#  'Celebrity_doll.html',
#  'Venezuelan_referendum,_1957.html',
#  'Australian_hardcore.html',
#  'Lake_County_Examiner.html',
#  'HMS_Robust.html',
#  '985_Innovative_Platforms_for_Key_Disciplines_Project.html',
#  'Hermann_Nuding.html',
#  'Love,_Sax_and_Flashbacks.html',
#  'Kolound.html',
#  'Ordinary,_Virginia.html',
#  'Kanakomyrtus.html',
#  'Bulbophyllum_biflorum.html',
#  'Copamyntis_infusella.html',
#  'Archiepiscopal_Palace,_Rouen.html',
#  'Charged_Records.html',
#  'Cosmopterix_similis.html',
#  'Jyoti_Raju.html',
#  'Apocephalus_borealis.html',
#  'Bernard-Augustin_Conroy.html',
#  'Ready_or_Not_(Young_JV_album).html',
#  'Indhiya_Jananayaga_Katchi.html',
#  'St._Peter%27s_Church,_Tiberias.html',
#  'Parkgate_railway_station.html',
#  'C11orf30.html',
#  'Mr_Freedom_(fashion).html',
#  'Stade_Municipal_de_Djougou.html',
#  'Suwannee_River_Junior_College.html',
#  'Estelle_v._Smith.html',
#  'Arabic_Toilers%27_Movement.html',
#  'Koevtsi,_Gabrovo_Province.html',
#  'Kentucky_Auditor_election,_2011.html',
#  '2013_FIA_WTCC_Race_of_Russia.html',
#  'Taipa_Houses%E2%80%93Museum.html',
#  'Tobi_trousers.html',
#  'Museum_of_John_Paul_II_Collection.html',
#  'Gbiri-Niragu_language.html',
#  'Virajpet_(Vidhan_Sabha_constituency).html',
#  'List_of_people_from_Bangor,_Maine.html',
#  'One_Night_of_Sin.html',
#  'Cabrini%E2%80%93Green,_Chicago.html',
#  'Ek_Dil_Sau_Afsane.html',
#  'Pustiu_River.html',
#  'Majeepura.html',
#  'Tongyi,_Mingin.html',
#  'Zeiraphera.html',
#  'Benidorm_Bastards.html',
#  'Burmese_shrike.html',
#  'Axel_Revold.html',
#  '2009_World_Junior_Ice_Hockey_Championships_rosters.html',
#  'Qatar_at_the_2013_World_Championships_in_Athletics.html',
#  'Nepal_at_the_2008_Summer_Paralympics.html',
#  'Daniel_Cerone.html',
#  'Alan_Sheehan.html',
#  'Work_domain_analysis.html',
#  'Pochyta.html',
#  'Jarom%C3%ADr_%C5%A0imr.html',
#  'Simon%27s_Town_railway_station.html',
#  'Larvicide.html',
#  'Power_transfer_unit.html',
#  'Crab-eating_frog.html',
#  'Percy_William_Bunting.html',
#  'Meanings_of_minor_planet_names:_440,001%E2%80%93450,000.html',
#  'Chief_Justice_of_New_Zealand.html',
#  'KUMT.html',
#  'Vanavara_Airport.html',
#  'Lord_Howe%27s_action,_or_the_Glorious_First_of_June.html',
#  '55th_parallel_south.html',
#  'Aleksandra_Jagie%C5%82o.html',
#  'Curtis_Whitley.html',
#  'Post_(structural).html',
#  'Lake_Lagunitas.html',
#  'Failing_Office_Building.html',
#  'Carley_State_Park.html',
#  'Puerto_Rico_at_the_2013_World_Aquatics_Championships.html',
#  'Eyes_Galaxies.html',
#  'Kistenuten.html',
#  'Children_of_the_Grave.html',
#  'Bagrat_VI_of_Georgia.html',
#  'Pushkar.html',
#  'List_of_Uzbek_films_of_2014.html',
#  'Konstantin_%22Samokovetsa%22_Dimitrov.html',
#  'Cygany,_Masovian_Voivodeship.html',
#  'KMTZ.html',
#  'Football_Foundation.html',
#  'Ministry_of_Development_Planning_and_Statistics.html',
#  'Caney_Creek_(Matagorda_Bay).html',
#  'Solanum_chilliasense.html',
#  'Ballard_Memorial_High_School.html',
#  'Thanks_Again.html',
#  'Dowell_Philip_O%27Reilly.html',
#  'The_Land_of_the_Dead.html',
#  'Yoshinkan.html',
#  'John_Maitland_(Royal_Navy_officer).html',
#  'Social_dualism.html',
#  'Golabkhvaran.html',
#  'Liebig_Peak.html',
#  'Garrett_Lucash.html',
#  'Medical_Unit,_Self-contained,_Transportable.html',
#  '1st_Strategic_Aerospace_Division.html',
#  'Agnolin.html',
#  'Wren,_Alabama.html',
#  'Roselawn,_Indiana.html',
#  'Brograve_Mill.html',
#  'Ashley,_Wisconsin.html',
#  'Blue_SWAT.html',
#  'HMS_Stratagem_(P234).html',
#  'Poor_Richard%27s_Almanack_(TV_series).html',
#  'Pedro_Checa.html',
#  'Martha_Herbert.html',
#  'Goodnight%E2%80%93Loving_Trail.html',
#  'Adolf_Schulte.html',
#  'Danish_Maritime_Safety_Administration.html',
#  'Kiev_Missal.html',
#  'Don_Raye.html',
#  'Precorrin-6A_reductase.html',
#  'Strawberry_foliar_nematode.html',
#  'St._Paul_University_Iloilo.html',
#  'Roger_Brooke.html',
#  'Doumanaba.html',
#  'H._Larue_Renfroe.html',
#  'Giants%27_grave_of_S%27Ena%27e_Thomes.html',
#  'Crepidula_atrasolea.html',
#  'Sahanpur.html',
#  'Ksar_Nalut.html',
#  'Phong_Th%E1%BA%A1nh_%C4%90%C3%B4ng_A.html',
#  'Martinus_Hamconius.html',
#  'Sanford_Wallace.html',
#  'Gratitud.html',
#  'Al-Midan.html',
#  'Iwaki-Ishikawa_Station.html',
#  'Abraham_Stanyan.html',
#  'U.S._Snowboarding_Race_to_the_Cup.html',
#  'Seminemacheilus.html',
#  'British_Academy_Television_Award_for_Best_Comedy_(Programme_or_Series).html',
#  'FC_Bobruisk.html',
#  '2011_UK_Open_Qualifier_4.html',
#  'Monarch_Mountain.html',
#  'Johnny_B._Moore.html',
#  'Ayish_Bayou.html',
#  'Newton_Stone.html',
#  'Treaty_of_Ryswick.html',
#  'Kenneth_van_Kempen.html',
#  'Progressive_refinement.html',
#  'Zoom_Systems.html',
#  'Panchamrutham.html',
#  'Hoghiz.html',
#  'Peltigera_membranacea.html',
#  'Bazemore,_Alabama.html',
#  'Ovum_Recordings.html',
#  'Dick_Johnson_(clarinetist).html',
#  'Urodilatin.html',
#  'Stephen_Unwin_(director).html',
#  'Columbia_Airport_(Ohio).html',
#  'Shibanov.html',
#  'DWTE-TV.html',
#  'Bifidocarpus.html',
#  'Priscus_of_Epirus.html',
#  'Bibiana_Beglau.html',
#  'Ordinary_singularity.html',
#  'Castle_of_Cardona.html',
#  'Emmanuel_Muhammad.html',
#  'Bulbonaricus.html',
#  'Kelvin_Mbilinyi.html',
#  'Emily_(1964_song).html',
#  'Ricard_Card%C3%BAs.html',
#  'Greg_Halsey-Brandt.html',
#  'Kim_Yong-hwa.html',
#  'Queensland_Music_Festival.html',
#  'Clay_Township,_Clark_County,_Missouri.html',
#  'Liberty_Central_School_District.html',
#  'Kamakshyanagar.html',
#  'S%C3%A3o_Sebasti%C3%A3o_do_Alto.html',
#  'Kattukukke.html',
#  'Tischofer_Cave.html',
#  'Rob_Jones_(footballer,_born_1971).html',
#  'Embraer_Unidade_Gavi%C3%A3o_Peixoto_Airport.html',
#  'Barren_vegetation.html',
#  'Burbridge_Creek.html',
#  'Bye!_My_Boy!.html',
#  'Phil_Spence.html',
#  'Ronald_McCaffer.html',
#  'Macy_conferences.html',
#  'Belgium_women%27s_national_field_hockey_team.html',
#  'Dalian_Road_Station.html',
#  'Antonio_de_Zayas_(bishop).html',
#  'Oldham_Metropolitan_Borough_Council_election,_2000.html',
#  'Hideki_Kase.html',
#  'Acceptance_(Heroes).html',
#  'Enamul_Haque_(cricketer,_born_1966).html',
#  'RF_microwave_CAE_CAD.html',
#  'Ego_Dominus_Tuus.html',
#  'High_Efficiency_Image_File_Format.html',
#  'New_York_Women_Composers,_Inc..html',
#  'Newfoundland_general_election,_1848.html',
#  'Lungujja.html',
#  'Smeaton,_East_Lothian.html',
#  'Government_Polytechnic_Nagriya_Mod_Etah.html',
#  'Ma_Sen.html',
#  'Phenacobius_catostomus.html',
#  'Norderbrarup.html',
#  'Octomeria_lithophila.html',
#  'Joint_Committee_for_Traceability_in_Laboratory_Medicine.html',
#  'Yuga_(film).html',
#  'Clay_Research_Award.html',
#  'Kreslyuvtsi.html',
#  '33rd_New_Jersey_Volunteer_Infantry.html',
#  'Steinkjersannan.html',
#  'Carthage,_Cincinnati.html',
#  'Senapati_district.html',
#  'Frost_Township,_Michigan.html',
#  'Bay_of_Concepci%C3%B3n.html',
#  'Chhaparband_(Muslim).html',
#  'Guaricana_National_Park.html',
#  'Challenger_Banque_Nationale_de_Drummondville.html',
#  'Appa_(film).html',
#  'Ben_H._Williams.html',
#  'Hypocysta_angustata.html',
#  'Copenhagen_Skatepark.html',
#  'Saratoga_Automobile_Museum.html',
#  'Madhuri_Desai.html',
#  'Athletics_at_the_1994_Commonwealth_Games_%E2%80%93_Men%27s_pole_vault.html',
#  'Odder.html',
#  'Aldona_Orman.html',
#  'Vancouver_Furious_George.html',
#  'Havnar_R%C3%B3%C3%B0rarfelag.html',
#  'Dextran_1.html',
#  'HD_90156.html',
#  'WFGI-FM.html',
#  'Oculo-respiratory_syndrome.html',
#  'Zhongxing_Guesthouse.html',
#  '1988_State_of_Origin_series.html',
#  'Hemiargyropsis_frontalis.html',
#  'The_Audacity_to_Podcast.html',
#  'List_of_Polish_consorts.html',
#  'Third_Saturday_in_October.html',
#  'Antipater_of_Thessalonica.html',
#  'Santa_Maria_Imbaro.html',
#  'Brownfield_(software_development).html',
#  'George_Joseph_Trapp.html',
#  'Russell_Road_(Ontario).html',
#  'Maneswar_Brahma.html',
#  'Robin_Brooke.html',
#  '100_Greatest_Romanians.html',
#  'Cristian_Berdeja.html',
#  'King_Parker_House.html',
#  'Al-Nurayn_Mosque.html',
#  'John_Shaw_Rennie.html',
#  'Sobolewo,_Wysokie_Mazowieckie_County.html',
#  'Meneng_Constituency.html',
#  'List_of_Spaghetti_Western_films.html',
#  'Paul_Kenny_(politician).html',
#  'Luca_Luciano.html',
#  'Cannabis_in_Spain.html',
#  'VSX2.html',
#  'Varsity_College.html',
#  'Fahy,_County_Mayo.html',
#  'Keegan_Pereira_(footballer).html',
#  'Eudonia_notozeucta.html',
#  'Pirama.html',
#  'Shinpei_Matsushita.html',
#  'Boardman_Township,_Mahoning_County,_Ohio.html',
#  'Anton_von_Troeltsch.html',
#  'Vang_stone.html',
#  'Heinz_Inniger.html',
#  'Marion_Rockefeller_Weber.html',
#  'Abdulla_Majid_Al_Naimi.html',
#  'The_Future_(film).html',
#  'Fusinus_carvalhoriosi.html',
#  'List_of_Nymphaeales_of_Montana.html',
#  'Weiser_River.html',
#  'Elzear_Torreggiani.html',
#  'Scarlet_wrasse.html',
#  'Svinjare.html',
#  'G.O.Y.A._(Gunz_Or_Yay_Available).html',
#  'Switzerland_at_the_1992_Winter_Olympics.html',
#  'Chef_Wan.html',
#  'Viva_Villa!.html',
#  'Jon_Mullich.html',
#  'Clear_Creek_Township,_Cooper_County,_Missouri.html',
#  'A_Sport_and_a_Pastime.html',
#  'The_Right_Kinda_Lover.html',
#  'Plains,_Kansas.html',
#  'Baadj.html',
#  'George_Ellicott.html',
#  'Cortile_del_Belvedere.html',
#  'Mick_Kelly_(Australian_footballer).html',
#  'Somarasampettai.html',
#  'David_Jesson.html',
#  '%C5%8Cnog%C5%8D_Station.html',
#  'Nuno_Leal_Maia.html',
#  'Battle_of_Wattignies.html',
#  'Saravan,_Gilan.html',
#  'Colchester_Village_Historic_District.html',
#  'Watsonville_Junction,_California.html',
#  'Hayateumi_Hidehito.html',
#  'Oliver_Twist_(1912_American_film).html',
#  'Omar_Onsi.html',
#  'Utiel-Requena.html',
#  'Volume_One_(The_West_Coast_Pop_Art_Experimental_Band_album).html',
#  'Pozna%C5%84_Wola_railway_station.html',
#  'ISMACryp.html',
#  'Mirisah.html',
#  'USS_Impeccable_(AM-320).html',
#  'Bengt_Forsberg.html',
#  'Irihirose_Station.html',
#  'A_Month_of_Sundays_(miniseries).html',
#  'Teiji_Ito.html',
#  'Robert_E._Lee_(FCC).html',
#  'Giardini_Margherita.html',
#  'Upper_Beaches.html',
#  'Minister_of_Foreign_Affairs_(Egypt).html',
#  'Italian_submarine_Comandante_Fa%C3%A0_di_Bruno.html',
#  'Christine_Gardner.html',
#  'Durham_Women%27s_F.C..html',
#  'USS_Rose_Mary_(SP-1216).html',
#  'Shoreyjeh-ye_Do.html',
#  '%C3%89cole_des_Mines_de_Douai.html',
#  'Luciano_Mercante.html',
#  'Jeff_Boyd.html',
#  'Abbeville_Sluggers.html',
#  'East_Down_(Northern_Ireland_Parliament_constituency).html',
#  'Russian_Cultural_Centre_(Lviv).html',
#  'Morten_Rutkj%C3%A6r.html',
#  'Du%C5%A1anovo.html',
#  'Bowie_Race_Track.html',
#  'Gemma_Doyle_(politician).html',
#  'Thornton-le-Beans.html',
#  'Tommy_Hunter_(baseball).html',
#  'S%C3%B8rli.html',
#  'Frithjof_Schmidt.html',
#  'ARA_Garibaldi.html',
#  'How_Can_We_Hang_On_to_a_Dream%3F.html',
#  'Schwobsheim.html',
#  'Arrondissements_of_the_Yvelines_department.html',
#  'L._Fry.html',
#  'Hepatitis_B_virus.html',
#  'Jordan_Steel.html',
#  'Central_Luzon.html',
#  'Jack_Graham_(pastor).html',
#  'Sentences_(composition).html',
#  'Tropical_sprue.html',
#  'Elisa_von_der_Recke.html',
#  'Neurotica.html',
#  'Roxbury_Presbyterian_Church.html',
#  'Moosavi_Peace_Formula.html',
#  'Acrolophus_simulatus.html',
#  'Dennis_Chapman.html',
#  'Uruguayan_constitutional_referendum,_2014.html',
#  'Peter_Collingwood.html',
#  'List_of_molecular_graphics_systems.html',
#  'MOUSE_DHI.html',
#  'Hexachaeta_colombiana.html',
#  'Sot%C4%81panna.html',
#  '2015%E2%80%9316_Washington_Huskies_men%27s_basketball_team.html',
#  'Oligocentris_deciusalis.html',
#  '2008_Fed_Cup_World_Group_II.html',
#  'Camp_Liberty_killings.html',
#  'Hemet_Public_Library.html',
#  'Lin_Chia-yu.html',
#  'Omiodes_iridias.html',
#  'Shigeo_Kurata.html',
#  'Arthur_L._Aidala.html',
#  'Clocking_Out_Is_for_Suckers.html',
#  'List_of_gold_medalists_at_2006_South_Asian_Games.html',
#  'Gew%C3%A4chshaus_f%C3%BCr_tropische_Nutzpflanzen.html',
#  'The_Purpose_Driven_Church.html',
#  'Brendan_Foster.html',
#  'I%27m_Walking_Behind_You.html',
#  'Glinka_(crater).html',
#  'Larry_Brooks.html',
#  'Socket_423.html',
#  'Double_Wing_Attack.html',
#  'Arkansas_Highway_178.html',
#  'Taylour_Paige.html',
#  'Fraser_Lake_Airport.html',
#  'Potheri_village,_Kanchipuram.html',
#  'Pedro_Machuca.html',
#  'Roll%27s_partridge.html',
#  'Nejat_Alp.html',
#  'Checkerspot_(magazine).html',
#  'Functoid.html',
#  'Manitoba_general_election,_1896.html',
#  'Roman_Catholic_Diocese_of_Cervia.html',
#  'Lopez_v._Davis.html',
#  'Coenaculum_secundum.html',
#  'Football_at_the_National_Games_of_China.html',
#  'Vojin_%C4%86etkovi%C4%87.html',
#  'Sibling_Revelry.html',
#  'Isaac_Gr%C3%BCnewald.html',
#  'Waldoboro_(CDP),_Maine.html',
#  'Cecyl%C3%B3wka-Brz%C3%B3zka.html',
#  'List_of_birds_of_Malta.html',
#  '2009_English_cricket_season.html',
#  'Banovina_of_Croatia.html',
#  'Dakar_2:_The_World%27s_Ultimate_Rally.html',
#  'Anthony_Marten.html',
#  'Arcadio_Gonz%C3%A1lez.html',
#  'Boogie_Bunnies.html',
#  'Roque_P%C3%A9rez_Partido.html',
#  'Andrei_Gamalyan.html',
#  'Mykines,_Greece.html',
#  'Dresden-Plauen_railway_station.html',
#  'Kailas_Pal.html',
#  'Bad_Luck_(Social_Distortion_song).html',
#  'I,_Q_(book_series).html',
#  'Julien_Boisselier.html',
#  'Turkish_Men%27s_Volleyball_Championship.html',
#  'Joint_Social_Welfare_Institute.html',
#  'The_Summer_King.html',
#  'Burnin%27_Sneakers.html',
#  'Chapel_of_Mercy,_Monaco-Ville.html',
#  'Jazz_in_Turkey.html',
#  'Burnley_Borough_Council_election,_2011.html',
#  'National_Register_of_Historic_Places_listings_in_Allen_Parish,_Louisiana.html',
#  'Luiz_Henrique_Santos.html',
#  'Yasid.html',
#  '2001_NCAA_Division_I_Field_Hockey_Championship.html',
#  'Ctenodes_zonata.html',
#  'EDP_Sarichioi_Wind_Farm.html',
#  'Carte_Imagine%27R.html',
#  'Holly_Golightly_(comics).html',
#  'Johann_Christoph_Hoffbauer.html',
#  'Matthew_Liptak.html',
#  'Programa_Mejorando_tu_Autoestima.html',
#  'Philaeus.html',
#  'Kate_Harwood.html',
#  'Baltic_Peak.html',
#  'Westchester,_Los_Angeles.html',
#  'Laredo_Colombia_Solidarity_Port_of_Entry.html',
#  '104th_Logistic_Support_Brigade_(United_Kingdom).html',
#  'Pichoy_Airfield.html',
#  'Wreck_Island_Natural_Area_Preserve.html',
#  'Desmiphora_bijuba.html',
#  'Webb_Dock_railway_line.html',
#  'Helena_Nyblom.html',
#  'Hall_of_Mental_Cultivation.html',
#  'John_Whewell.html',
#  '2014%E2%80%9315_Albanian_Third_Division.html',
#  'Gulliver_Mickey.html',
#  'Henry_Horace_Williams.html',
#  'Hebden_Bridge_Picture_House.html',
#  'Marie-Jos%C3%A8phe_Jude.html',
#  'Circus_Avenue.html',
#  'Kettu_Kalyanam.html',
#  'Union_United_Church.html',
#  'Bill_Overstreet.html',
#  'Urs_Burkart.html',
#  'The_K_of_D.html',
#  'Gandigwad.html',
#  'Kentucky_Theater.html',
#  'USS_General_Putnam_(1857).html',
#  'George_Jones_(bishop).html',
#  'United_Nations_Security_Council_Resolution_1923.html',
#  'The_Hackensaw_Boys.html',
#  'Harry_Sacksioni.html',
#  'David_Beasley.html',
#  'Piracy_on_Falcon_Lake.html',
#  'Mammoth_Unified_School_District.html',
#  'Eggerberg_railway_station.html',
#  'Tillandsia_intermedia.html',
#  'Town_Yetholm.html',
#  'S%27portable_Scoreboards.html',
#  'Sparganothis_saracana.html',
#  'Smilax_laurifolia.html',
#  'Taylor_Williamson.html',
#  'Epropetes_metallica.html',
#  'Melanolagus_bericoides.html',
#  'BBCH-scale_(rice).html',
#  'La_Roca_de_la_Sierra.html',
#  'Russian_Party_in_Estonia.html',
#  'Henry_Louis_Larsen.html',
#  'Torovirinae.html',
#  'Moses_Hardy.html',
#  '1896_Indiana_Hoosiers_football_team.html',
#  'Els_Dottermans.html',
#  'Epichorista.html',
#  'Ownership_of_Rangers_F.C..html',
#  'Clinton_Engineer_Works.html',
#  'It%27s_Just_My_Funny_Way_of_Laughin%27.html',
#  'The_Showdown_Effect.html',
#  'My_Life_(Billy_Joel_song).html',
#  'Ramo_Stott.html',
#  'Geomancer_(comics).html',
#  'Enrique_Morales.html',
#  'Linowiec,_Kuyavian-Pomeranian_Voivodeship.html',
#  'Triptolemus_Evrychou.html',
#  'Claudia_Neidig.html',
#  'Keshav_Ginde.html',
#  'Cyclohexane_conformation.html',
#  'Dean_Kukan.html',
#  'List_of_Carboniferous_tetrapods.html',
#  'Sol_Orwell.html',
#  'Lucius_Allen_(politician).html',
#  'Elio_Calderini.html',
#  'Demographics_of_American_Samoa.html',
#  'Middle_Park,_Victoria.html',
#  'Peringiella_denticulata.html',
#  'Y%C3%AAn_B%C3%A1i.html',
#  'Young_Finnish_Party.html',
#  'Rudy:_The_Rudy_Giuliani_Story.html',
#  'Dysgonia_pudica.html',
#  'Klaus_Gerwien.html',
#  'Lee_Henderson_Watkins.html',
#  '%C3%89taule.html',
#  'Sabari.html',
#  'Timothy_Wanyonyi_Wetangula.html',
#  'Ivo_Siromahov.html',
#  'John_Jephson.html',
#  'Land_%26_Water_Australia.html',
#  'Shabbir_Kumar.html',
#  'Sylvia_Moss.html',
#  'West_Park_Bridge.html',
#  'Imperial_amazon.html',
#  '16th_Virginia_Infantry.html',
#  'North_Coast_(RTA_Rapid_Transit_station).html',
#  'Alex_McEachern.html',
#  'Kate_Quarrie.html',
#  'Cyclone_Gamede.html',
#  'William_McDonald_(Australian_politician).html']

# %%
len(os.listdir("wiki"))
# Out:
# 999

# %%
with open("wiki/Neville_Hewitt_(American_football).html") as f:
    print(f.read())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Neville Hewitt (American football) - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Neville_Hewitt_(American_football)","wgTitle":"Neville Hewitt (American football)","wgCurRevisionId":759899379,"wgRevisionId":759899379,"wgArticleId":47925396,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Miami Dolphins currentteam parameter articles","1993 births","Living people","Undrafted National Football League players","American football linebackers","Marshall Thundering Herd football players","Miami Dolphins players"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Neville_Hewitt_(American_football)","wgRelevantArticleId":47925396,"wgRequestId":"WLjfJQpAME0AAGF0uOoAAAAM","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":false,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesBetaFeatureEnabled":false,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikibaseItemId":"Q21621474","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options@0j3lz3q",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens@1dqfd7l",function ( $, jQuery, require, module ) {
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/;
#
# });mw.loader.load(["ext.cite.a11y","mediawiki.action.view.postEdit","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.legacy.wikibits","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.gadget.featured-articles-links","ext.centralauth.centralautologin","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});</script>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.29.0-wmf.14"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Neville_Hewitt_(American_football)"/>
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=Neville_Hewitt_(American_football)&amp;action=edit"/>
# <link rel="edit" title="Edit this page" href="/w/index.php?title=Neville_Hewitt_(American_football)&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="copyright" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://en.wikipedia.org/wiki/Neville_Hewitt_(American_football)"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Neville_Hewitt_American_football rootpage-Neville_Hewitt_American_football skin-vector action-view">		<div id="mw-page-base" class="noprint"></div>
# 		<div id="mw-head-base" class="noprint"></div>
# 		<div id="content" class="mw-body" role="main">
# 			<a id="top"></a>
#
# 							<div id="siteNotice"><!-- CentralNotice --></div>
# 						<div class="mw-indicators">
# </div>
# 			<h1 id="firstHeading" class="firstHeading" lang="en">Neville Hewitt (American football)</h1>
# 									<div id="bodyContent" class="mw-body-content">
# 									<div id="siteSub">From Wikipedia, the free encyclopedia</div>
# 								<div id="contentSub"></div>
# 												<div id="jump-to-nav" class="mw-jump">
# 					Jump to:					<a href="#mw-head">navigation</a>, 					<a href="#p-search">search</a>
# 				</div>
# 				<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><table class="infobox vcard" style="width:22em;width: 25em; font-size: 95%; line-height: 1.2em;">
# <caption class="fn" style="line-height: initial;pastco">Neville Hewitt</caption>
# <tr>
# <th colspan="2" style="text-align:center;background: #008E97; color:white;border:2.5px solid  #F58220;; line-height: 1.5em;">No. 46 <span class="org">Miami Dolphins</span></th>
# </tr>
# <tr>
# <th scope="row" style="text-align: right; width: 40%;">Position:</th>
# <td><a href="/wiki/Linebacker" title="Linebacker">Linebacker</a></td>
# </tr>
# <tr>
# <th colspan="2" style="text-align:center;background: #008E97; color:white;border:2.5px solid  #F58220;; line-height: 1.5em;">Personal information</th>
# </tr>
# <tr>
# <th scope="row" style="text-align: right; width: 40%;"><span class="nowrap">Date of birth:</span></th>
# <td><span style="display:none">(<span class="bday">1993-04-06</span>)</span> April 6, 1993 <span class="noprint ForceAgeToShow">(age&#160;23)</span></td>
# </tr>
# <tr>
# <th scope="row" style="text-align: right; width: 40%;">Height:</th>
# <td>6&#160;ft 2&#160;in (1.88&#160;m)</td>
# </tr>
# <tr>
# <th scope="row" style="text-align: right; width: 40%;">Weight:</th>
# <td>235&#160;lb (107&#160;kg)</td>
# </tr>
# <tr>
# <th colspan="2" style="text-align:center;background: #008E97; color:white;border:2.5px solid  #F58220;; line-height: 1.5em;">Career information</th>
# </tr>
# <tr>
# <th scope="row" style="text-align: right; width: 40%;">College:</th>
# <td><a href="/wiki/Marshall_Thundering_Herd_football" title="Marshall Thundering Herd football">Marshall</a></td>
# </tr>
# <tr>
# <th scope="row" style="text-align: right; width: 40%;">Undrafted:</th>
# <td><a href="/wiki/2015_NFL_draft#Notable_undrafted_players" class="mw-redirect" title="2015 NFL draft">2015</a></td>
# </tr>
# <tr>
# <th colspan="2" style="text-align:center;background: #008E97; color:white;border:2.5px solid  #F58220;; line-height: 1.5em;">Career history</th>
# </tr>
# <tr>
# <td colspan="2" style="text-align:center;text-align: left; line-height: 1.4em;">
# <ul>
# <li><a href="/wiki/Miami_Dolphins" title="Miami Dolphins">Miami Dolphins</a> (<a href="/wiki/2015_NFL_season" title="2015 NFL season">2015</a>–present)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <th scope="row" style="text-align: right; width: 40%;">Roster status:</th>
# <td>Active</td>
# </tr>
# <tr>
# <th colspan="2" style="text-align:center;background: #008E97; color:white;border:2.5px solid  #F58220;; line-height: 1.5em;">Career highlights and awards</th>
# </tr>
# <tr>
# <td colspan="2" style="text-align:center;text-align: left; line-height: 1.4em;">
# <ul>
# <li>C-USA Defensive Player of the year (2014)</li>
# </ul>
# </td>
# </tr>
# <tr>
# <th colspan="2" style="text-align:center;background: #008E97; color:white;border:2.5px solid  #F58220;; line-height: 1.5em;">Career NFL statistics as of Week 17, 2016</th>
# </tr>
# <tr>
# <td colspan="2" style="text-align:center">
# <table class="infobox" style="width:22em;border-collapse:collapse; border-spacing:0px; border:none; width:100%; margin:0px; font-size:100%; clear:none; float:none">
# <tr>
# <th scope="row" style="text-align: right; width:50%;">Total tackles:</th>
# <td>103</td>
# </tr>
# <tr>
# <th scope="row" style="text-align: right; width:50%;">Sacks:</th>
# <td>1.0</td>
# </tr>
# <tr>
# <th scope="row" style="text-align: right; width:50%;"><a href="/wiki/Interception" title="Interception">Interceptions</a>:</th>
# <td>1</td>
# </tr>
# <tr>
# <td colspan="2" style="text-align:center">Player stats at <b><a rel="nofollow" class="external text" href="http://www.nfl.com/player/nevillehewitt/2553657/profile">NFL.com</a></b></td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# <p><b>Neville Hewitt</b> (born April 6, 1993) is an <a href="/wiki/American_football" title="American football">American football</a> <a href="/wiki/Inside_linebacker" class="mw-redirect" title="Inside linebacker">inside linebacker</a> for the <a href="/wiki/Miami_Dolphins" title="Miami Dolphins">Miami Dolphins</a> of the <a href="/wiki/National_Football_League" title="National Football League">National Football League</a> (NFL). He played <a href="/wiki/College_football" title="College football">college football</a> at <a href="/wiki/Marshall_University" title="Marshall University">Marshall University</a>, where he was a safety and linebacker. Hewitt signed with the Miami Dolphins as an <a href="/wiki/Undrafted_free_agent" class="mw-redirect" title="Undrafted free agent">undrafted free agent</a> in 2015.</p>
# <h2><span class="mw-headline" id="Professional_career">Professional career</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Neville_Hewitt_(American_football)&amp;action=edit&amp;section=1" title="Edit section: Professional career">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>On May 2, 2015, Hewitt signed with the Miami Dolphins as an undrafted free agent following the conclusion of the <a href="/wiki/2015_NFL_Draft" title="2015 NFL Draft">2015 NFL Draft</a>.<sup id="cite_ref-1" class="reference"><a href="#cite_note-1">[1]</a></sup></p>
# <h2><span class="mw-headline" id="References">References</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Neville_Hewitt_(American_football)&amp;action=edit&amp;section=2" title="Edit section: References">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="reflist" style="list-style-type: decimal;">
# <ol class="references">
# <li id="cite_note-1"><span class="mw-cite-backlink"><b><a href="#cite_ref-1">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.sun-sentinel.com/sports/miami-dolphins/fl-dolphins-undrafted-linebackers-0513-20150512-story.html">"Dolphins' undrafted linebackers have sights set on earning a roster spot"</a>. <i>sun-sentinel.com</i><span class="reference-accessdate">. Retrieved <span class="nowrap">May 12,</span> 2015</span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ANeville+Hewitt+%28American+football%29&amp;rft.atitle=Dolphins%27+undrafted+linebackers+have+sights+set+on+earning+a+roster+spot&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.sun-sentinel.com%2Fsports%2Fmiami-dolphins%2Ffl-dolphins-undrafted-linebackers-0513-20150512-story.html&amp;rft.jtitle=sun-sentinel.com&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# </ol>
# </div>
# <h2><span class="mw-headline" id="External_links">External links</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Neville_Hewitt_(American_football)&amp;action=edit&amp;section=3" title="Edit section: External links">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul>
# <li><a rel="nofollow" class="external text" href="http://www.herdzone.com/sports/m-footbl/mtt/neville_hewitt_857583.html">Marshall bio</a></li>
# <li><a rel="nofollow" class="external text" href="http://www.miamidolphins.com/team/roster/Neville-Hewitt/a402ce3c-78fd-4536-abdf-d053e7f86f8c">Miami Dolphins bio</a></li>
# </ul>
# <div role="navigation" class="navbox" aria-labelledby="Miami_Dolphins_current_roster" style="width:100%;;padding:3px">
# <table class="nowraplinks collapsible autocollapse navbox-inner" style="border-spacing:0;background:transparent;color:inherit">
# <tr>
# <th scope="col" class="navbox-title" colspan="2" style="background: #008E97; color:white;border:2.5px solid  #F58220;">
# <div class="plainlinks hlist navbar mini">
# <ul>
# <li class="nv-view"><a href="/wiki/Template:Miami_Dolphins_roster_navbox" title="Template:Miami Dolphins roster navbox"><abbr title="View this template" style="background: #008E97; color:white;border:2.5px solid  #F58220;;;background:none transparent;border:none;">v</abbr></a></li>
# <li class="nv-talk"><a href="/wiki/Template_talk:Miami_Dolphins_roster_navbox" title="Template talk:Miami Dolphins roster navbox"><abbr title="Discuss this template" style="background: #008E97; color:white;border:2.5px solid  #F58220;;;background:none transparent;border:none;">t</abbr></a></li>
# <li class="nv-edit"><a class="external text" href="//en.wikipedia.org/w/index.php?title=Template:Miami_Dolphins_roster_navbox&amp;action=edit"><abbr title="Edit this template" style="background: #008E97; color:white;border:2.5px solid  #F58220;;;background:none transparent;border:none;">e</abbr></a></li>
# </ul>
# </div>
# <div id="Miami_Dolphins_current_roster" style="font-size:114%"><a href="/wiki/Miami_Dolphins" title="Miami Dolphins"><span style="color:white">Miami Dolphins</span></a> current roster</div>
# </th>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <th scope="row" class="navbox-group" style="background: #008E97; color:white;border:2.5px solid  #F58220;">Active roster</th>
# <td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li>3&#160;<a href="/wiki/Andrew_Franks" title="Andrew Franks">Andrew&#160;Franks</a></li>
# <li>4&#160;<a href="/wiki/Matt_Darr" title="Matt Darr">Matt&#160;Darr</a></li>
# <li>6&#160;<a href="/wiki/Brandon_Doughty" title="Brandon Doughty">Brandon&#160;Doughty</a></li>
# <li>8&#160;<a href="/wiki/Matt_Moore_(American_football)" title="Matt Moore (American football)">Matt&#160;Moore</a></li>
# <li>10&#160;<a href="/wiki/Kenny_Stills" title="Kenny Stills">Kenny&#160;Stills</a></li>
# <li>11&#160;<a href="/wiki/DeVante_Parker" title="DeVante Parker">DeVante&#160;Parker</a></li>
# <li>14&#160;<a href="/wiki/Jarvis_Landry" title="Jarvis Landry">Jarvis&#160;Landry</a></li>
# <li>16&#160;<a href="/wiki/T._J._Yates" title="T. J. Yates">T.&#160;J.&#160;Yates</a></li>
# <li>17&#160;<a href="/wiki/Ryan_Tannehill" title="Ryan Tannehill">Ryan&#160;Tannehill</a></li>
# <li>19&#160;<a href="/wiki/Jakeem_Grant" title="Jakeem Grant">Jakeem&#160;Grant</a></li>
# <li>20&#160;<a href="/wiki/Reshad_Jones" title="Reshad Jones">Reshad&#160;Jones</a></li>
# <li>21&#160;<a href="/wiki/Jordan_Lucas" title="Jordan Lucas">Jordan&#160;Lucas</a></li>
# <li>23&#160;<a href="/wiki/Jay_Ajayi" title="Jay Ajayi">Jay&#160;Ajayi</a></li>
# <li>24&#160;<a href="/wiki/Isa_Abdul-Quddus" title="Isa Abdul-Quddus">Isa&#160;Abdul-Quddus</a></li>
# <li>25&#160;<a href="/wiki/Xavien_Howard" title="Xavien Howard">Xavien&#160;Howard</a></li>
# <li>26&#160;<a href="/wiki/Damien_Williams_(running_back)" title="Damien Williams (running back)">Damien&#160;Williams</a></li>
# <li>27&#160;<a href="/wiki/Storm_Johnson" title="Storm Johnson">Storm&#160;Johnson</a></li>
# <li>28&#160;<a href="/wiki/Bobby_McCain" title="Bobby McCain">Bobby&#160;McCain</a></li>
# <li>30&#160;<a href="/wiki/Bacarri_Rambo" title="Bacarri Rambo">Bacarri&#160;Rambo</a></li>
# <li>31&#160;<a href="/wiki/Michael_Thomas_(defensive_back)" title="Michael Thomas (defensive back)">Michael&#160;Thomas</a></li>
# <li>32&#160;<a href="/wiki/Kenyan_Drake" title="Kenyan Drake">Kenyan&#160;Drake</a></li>
# <li>34&#160;<a href="/wiki/Senorise_Perry" title="Senorise Perry">Senorise&#160;Perry</a></li>
# <li>35&#160;<a href="/wiki/Walt_Aikens" title="Walt Aikens">Walt&#160;Aikens</a></li>
# <li>36&#160;<a href="/wiki/Tony_Lippett" title="Tony Lippett">Tony&#160;Lippett</a></li>
# <li>37&#160;<a href="/w/index.php?title=A._J._Hendy&amp;action=edit&amp;redlink=1" class="new" title="A. J. Hendy (page does not exist)">A.&#160;J.&#160;Hendy</a></li>
# <li>38&#160;<a href="/w/index.php?title=Daniel_Davie&amp;action=edit&amp;redlink=1" class="new" title="Daniel Davie (page does not exist)">Daniel&#160;Davie</a></li>
# <li>40&#160;<a href="/wiki/Lafayette_Pitts" title="Lafayette Pitts">Lafayette&#160;Pitts</a></li>
# <li>41&#160;<a href="/wiki/Byron_Maxwell" title="Byron Maxwell">Byron&#160;Maxwell</a></li>
# <li>42&#160;<a href="/wiki/Spencer_Paysinger" title="Spencer Paysinger">Spencer&#160;Paysinger</a></li>
# <li>44&#160;<a href="/wiki/Deon_Lacey" title="Deon Lacey">Deon&#160;Lacey</a></li>
# <li>45&#160;<a href="/wiki/Mike_Hull_(linebacker)" title="Mike Hull (linebacker)">Mike&#160;Hull</a></li>
# <li>46&#160;<strong class="selflink">Neville&#160;Hewitt</strong></li>
# <li>47&#160;<a href="/wiki/Kiko_Alonso" title="Kiko Alonso">Kiko&#160;Alonso</a></li>
# <li>48&#160;<a href="/wiki/MarQueis_Gray" title="MarQueis Gray">MarQueis&#160;Gray</a></li>
# <li>49&#160;<a href="/wiki/Lamin_Barrow" title="Lamin Barrow">Lamin&#160;Barrow</a></li>
# <li>50&#160;<a href="/wiki/Andre_Branch" title="Andre Branch">Andre&#160;Branch</a></li>
# <li>51&#160;<a href="/wiki/Mike_Pouncey" title="Mike Pouncey">Mike&#160;Pouncey</a></li>
# <li>53&#160;<a href="/wiki/Jelani_Jenkins" title="Jelani Jenkins">Jelani&#160;Jenkins</a></li>
# <li>55&#160;<a href="/wiki/Koa_Misi" title="Koa Misi">Koa&#160;Misi</a></li>
# <li>56&#160;<a href="/wiki/Donald_Butler" title="Donald Butler">Donald&#160;Butler</a></li>
# <li>57&#160;<a href="/wiki/Trevor_Reilly" title="Trevor Reilly">Trevor&#160;Reilly</a></li>
# <li>58&#160;<a href="/wiki/Brandon_Watts" title="Brandon Watts">Brandon&#160;Watts</a></li>
# <li>60&#160;<a href="/wiki/Kraig_Urbik" title="Kraig Urbik">Kraig&#160;Urbik</a></li>
# <li>64&#160;<a href="/wiki/Jake_Brendel" title="Jake Brendel">Jake&#160;Brendel</a></li>
# <li>65&#160;<a href="/wiki/Anthony_Steen_(American_football)" title="Anthony Steen (American football)">Anthony&#160;Steen</a></li>
# <li>67&#160;<a href="/wiki/Laremy_Tunsil" title="Laremy Tunsil">Laremy&#160;Tunsil</a></li>
# <li>69&#160;<a href="/wiki/Terry_Poole_(American_football)" title="Terry Poole (American football)">Terry&#160;Poole</a></li>
# <li>70&#160;<a href="/wiki/Ja%27Wuan_James" title="Ja'Wuan James">Ja'Wuan&#160;James</a></li>
# <li>72&#160;<a href="/wiki/Arthur_Miley" title="Arthur Miley">Arthur&#160;Miley</a></li>
# <li>73&#160;<a href="/wiki/Julius_Warmsley" title="Julius Warmsley">Julius&#160;Warmsley</a></li>
# <li>74&#160;<a href="/wiki/Jermon_Bushrod" title="Jermon Bushrod">Jermon&#160;Bushrod</a></li>
# <li>75&#160;<a href="/wiki/Nick_Williams_(defensive_lineman)" title="Nick Williams (defensive lineman)">Nick&#160;Williams</a></li>
# <li>76&#160;<a href="/wiki/Branden_Albert" title="Branden Albert">Branden&#160;Albert</a></li>
# <li>77&#160;<a href="/w/index.php?title=Jesse_Davis_(American_football)&amp;action=edit&amp;redlink=1" class="new" title="Jesse Davis (American football) (page does not exist)">Jesse&#160;Davis</a></li>
# <li>78&#160;<a href="/wiki/Terrence_Fede" title="Terrence Fede">Terrence&#160;Fede</a></li>
# <li>79&#160;<a href="/wiki/Sam_Young_(American_football)" title="Sam Young (American football)">Sam&#160;Young</a></li>
# <li>80&#160;<a href="/wiki/Dion_Sims" title="Dion Sims">Dion&#160;Sims</a></li>
# <li>83&#160;<a href="/wiki/Thomas_Duarte" title="Thomas Duarte">Thomas&#160;Duarte</a></li>
# <li>84&#160;<a href="/wiki/Jordan_Cameron" title="Jordan Cameron">Jordan&#160;Cameron</a></li>
# <li>85&#160;<a href="/wiki/Dominique_Jones_(American_football)" title="Dominique Jones (American football)">Dominique&#160;Jones</a></li>
# <li>86&#160;<a href="/wiki/Chris_Pantale" title="Chris Pantale">Chris&#160;Pantale</a></li>
# <li>87&#160;<a href="/wiki/Rashawn_Scott" title="Rashawn Scott">Rashawn&#160;Scott</a></li>
# <li>88&#160;<a href="/wiki/Leonte_Carroo" title="Leonte Carroo">Leonte&#160;Carroo</a></li>
# <li>91&#160;<a href="/wiki/Cameron_Wake" title="Cameron Wake">Cameron&#160;Wake</a></li>
# <li>92&#160;<a href="/wiki/John_Denney" title="John Denney">John&#160;Denney</a></li>
# <li>93&#160;<a href="/wiki/Ndamukong_Suh" title="Ndamukong Suh">Ndamukong&#160;Suh</a></li>
# <li>95&#160;<a href="/wiki/Dion_Jordan" title="Dion Jordan">Dion&#160;Jordan</a></li>
# <li>97&#160;<a href="/wiki/Jordan_Phillips" title="Jordan Phillips">Jordan&#160;Phillips</a></li>
# <li>--&#160;<a href="/wiki/Lawrence_Okoye" title="Lawrence Okoye">Lawrence&#160;Okoye</a></li>
# <li>--&#160;<a href="/w/index.php?title=Winston_Chapman&amp;action=edit&amp;redlink=1" class="new" title="Winston Chapman (page does not exist)">Winston&#160;Chapman</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <td class="navbox-abovebelow" colspan="2" style="background: #008E97; color:white;border:2.5px solid  #F58220;">
# <div>
# <div class="hlist" style="font-size:smaller;color:white">
# <dl>
# <dt><a href="/wiki/American_Football_Conference" title="American Football Conference"><span style="color:white">AFC</span></a> <span style="font-weight:normal;"><i>East</i></span></dt>
# <dd><a href="/wiki/Template:Buffalo_Bills_roster_navbox" title="Template:Buffalo Bills roster navbox"><span style="color:white">BUF</span></a></dd>
# <dd><a href="/wiki/Template:Miami_Dolphins_roster_navbox" title="Template:Miami Dolphins roster navbox"><span style="color:white">MIA</span></a></dd>
# <dd><a href="/wiki/Template:New_England_Patriots_roster_navbox" title="Template:New England Patriots roster navbox"><span style="color:white">NE</span></a></dd>
# <dd><a href="/wiki/Template:New_York_Jets_roster_navbox" title="Template:New York Jets roster navbox"><span style="color:white">NYJ</span></a></dd>
# <dt><span style="font-weight:normal;"><i>North</i></span></dt>
# <dd><a href="/wiki/Template:Baltimore_Ravens_roster_navbox" title="Template:Baltimore Ravens roster navbox"><span style="color:white">BAL</span></a></dd>
# <dd><a href="/wiki/Template:Cincinnati_Bengals_roster_navbox" title="Template:Cincinnati Bengals roster navbox"><span style="color:white">CIN</span></a></dd>
# <dd><a href="/wiki/Template:Cleveland_Browns_roster_navbox" title="Template:Cleveland Browns roster navbox"><span style="color:white">CLE</span></a></dd>
# <dd><a href="/wiki/Template:Pittsburgh_Steelers_roster_navbox" title="Template:Pittsburgh Steelers roster navbox"><span style="color:white">PIT</span></a></dd>
# <dt><span style="font-weight:normal;"><i>South</i></span></dt>
# <dd><a href="/wiki/Template:Houston_Texans_roster_navbox" title="Template:Houston Texans roster navbox"><span style="color:white">HOU</span></a></dd>
# <dd><a href="/wiki/Template:Indianapolis_Colts_roster_navbox" title="Template:Indianapolis Colts roster navbox"><span style="color:white">IND</span></a></dd>
# <dd><a href="/wiki/Template:Jacksonville_Jaguars_roster_navbox" title="Template:Jacksonville Jaguars roster navbox"><span style="color:white">JAX</span></a></dd>
# <dd><a href="/wiki/Template:Tennessee_Titans_roster_navbox" title="Template:Tennessee Titans roster navbox"><span style="color:white">TEN</span></a></dd>
# <dt><span style="font-weight:normal;"><i>West</i></span></dt>
# <dd><a href="/wiki/Template:Denver_Broncos_roster_navbox" title="Template:Denver Broncos roster navbox"><span style="color:white">DEN</span></a></dd>
# <dd><a href="/wiki/Template:Kansas_City_Chiefs_roster_navbox" title="Template:Kansas City Chiefs roster navbox"><span style="color:white">KC</span></a></dd>
# <dd><a href="/wiki/Template:Los_Angeles_Chargers_roster_navbox" title="Template:Los Angeles Chargers roster navbox"><span style="color:white">LAC</span></a></dd>
# <dd><a href="/wiki/Template:Oakland_Raiders_roster_navbox" title="Template:Oakland Raiders roster navbox"><span style="color:white">OAK</span></a></dd>
# </dl>
# <dl>
# <dt><a href="/wiki/National_Football_Conference" title="National Football Conference"><span style="color:white">NFC</span></a> <span style="font-weight:normal;"><i>East</i></span></dt>
# <dd><a href="/wiki/Template:Dallas_Cowboys_roster_navbox" title="Template:Dallas Cowboys roster navbox"><span style="color:white">DAL</span></a></dd>
# <dd><a href="/wiki/Template:New_York_Giants_roster_navbox" title="Template:New York Giants roster navbox"><span style="color:white">NYG</span></a></dd>
# <dd><a href="/wiki/Template:Philadelphia_Eagles_roster_navbox" title="Template:Philadelphia Eagles roster navbox"><span style="color:white">PHI</span></a></dd>
# <dd><a href="/wiki/Template:Washington_Redskins_roster_navbox" title="Template:Washington Redskins roster navbox"><span style="color:white">WAS</span></a></dd>
# <dt><span style="font-weight:normal;"><i>North</i></span></dt>
# <dd><a href="/wiki/Template:Chicago_Bears_roster_navbox" title="Template:Chicago Bears roster navbox"><span style="color:white">CHI</span></a></dd>
# <dd><a href="/wiki/Template:Detroit_Lions_roster_navbox" title="Template:Detroit Lions roster navbox"><span style="color:white">DET</span></a></dd>
# <dd><a href="/wiki/Template:Green_Bay_Packers_roster_navbox" title="Template:Green Bay Packers roster navbox"><span style="color:white">GB</span></a></dd>
# <dd><a href="/wiki/Template:Minnesota_Vikings_roster_navbox" title="Template:Minnesota Vikings roster navbox"><span style="color:white">MIN</span></a></dd>
# <dt><span style="font-weight:normal;"><i>South</i></span></dt>
# <dd><a href="/wiki/Template:Atlanta_Falcons_roster_navbox" title="Template:Atlanta Falcons roster navbox"><span style="color:white">ATL</span></a></dd>
# <dd><a href="/wiki/Template:Carolina_Panthers_roster_navbox" title="Template:Carolina Panthers roster navbox"><span style="color:white">CAR</span></a></dd>
# <dd><a href="/wiki/Template:New_Orleans_Saints_roster_navbox" title="Template:New Orleans Saints roster navbox"><span style="color:white">NO</span></a></dd>
# <dd><a href="/wiki/Template:Tampa_Bay_Buccaneers_roster_navbox" title="Template:Tampa Bay Buccaneers roster navbox"><span style="color:white">TB</span></a></dd>
# <dt><span style="font-weight:normal;"><i>West</i></span></dt>
# <dd><a href="/wiki/Template:Arizona_Cardinals_roster_navbox" title="Template:Arizona Cardinals roster navbox"><span style="color:white">ARI</span></a></dd>
# <dd><a href="/wiki/Template:Los_Angeles_Rams_roster_navbox" title="Template:Los Angeles Rams roster navbox"><span style="color:white">LAR</span></a></dd>
# <dd><a href="/wiki/Template:San_Francisco_49ers_roster_navbox" title="Template:San Francisco 49ers roster navbox"><span style="color:white">SF</span></a></dd>
# <dd><a href="/wiki/Template:Seattle_Seahawks_roster_navbox" title="Template:Seattle Seahawks roster navbox"><span style="color:white">SEA</span></a></dd>
# </dl>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
#
#
# <!--
# NewPP limit report
# Parsed by mw1302
# Cached time: 20170303031127
# Cache expiry: 3600
# Dynamic content: true
# CPU time usage: 0.224 seconds
# Real time usage: 0.272 seconds
# Preprocessor visited node count: 2342/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 43722/2097152 bytes
# Template argument size: 3719/2097152 bytes
# Highest expansion depth: 15/40
# Expensive parser function count: 0/500
# Lua time usage: 0.086/10.000 seconds
# Lua memory usage: 3.49 MB/50 MB
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  242.459      1 -total
#  71.43%  173.182      1 Template:Infobox_NFL_player
#  70.10%  169.954      5 Template:Infobox
#  16.50%   40.006      1 Template:Miami_Dolphins_roster_navbox
#  15.65%   37.947      1 Template:Team_roster_navbox
#  15.21%   36.883      2 Template:Convinfobox
#  13.85%   33.592      2 Template:NFLPrimaryStyle
#  13.40%   32.488      1 Template:Convinfobox/prisec3
#  12.49%   30.290      2 Template:Convert
#  11.74%   28.459      1 Template:Reflist
# -->
#
# <!-- Saved in parser cache with key enwiki:pcache:idhash:47925396-0!*!*!!*!*!* and timestamp 20170303031127 and revision id 759899379
#  -->
# <noscript><img src="//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" alt="" title="" width="1" height="1" style="border: none; position: absolute;" /></noscript></div>					<div class="printfooter">
# 						Retrieved from "<a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=Neville_Hewitt_(American_football)&amp;oldid=759899379">https://en.wikipedia.org/w/index.php?title=Neville_Hewitt_(American_football)&amp;oldid=759899379</a>"					</div>
# 				<div id="catlinks" class="catlinks" data-mw="interface"><div id="mw-normal-catlinks" class="mw-normal-catlinks"><a href="/wiki/Help:Category" title="Help:Category">Categories</a>: <ul><li><a href="/wiki/Category:1993_births" title="Category:1993 births">1993 births</a></li><li><a href="/wiki/Category:Living_people" title="Category:Living people">Living people</a></li><li><a href="/wiki/Category:Undrafted_National_Football_League_players" title="Category:Undrafted National Football League players">Undrafted National Football League players</a></li><li><a href="/wiki/Category:American_football_linebackers" title="Category:American football linebackers">American football linebackers</a></li><li><a href="/wiki/Category:Marshall_Thundering_Herd_football_players" title="Category:Marshall Thundering Herd football players">Marshall Thundering Herd football players</a></li><li><a href="/wiki/Category:Miami_Dolphins_players" title="Category:Miami Dolphins players">Miami Dolphins players</a></li></ul></div><div id="mw-hidden-catlinks" class="mw-hidden-catlinks mw-hidden-cats-hidden">Hidden categories: <ul><li><a href="/wiki/Category:Miami_Dolphins_currentteam_parameter_articles" title="Category:Miami Dolphins currentteam parameter articles">Miami Dolphins currentteam parameter articles</a></li></ul></div></div>				<div class="visualClear"></div>
# 							</div>
# 		</div>
# 		<div id="mw-navigation">
# 			<h2>Navigation menu</h2>
#
# 			<div id="mw-head">
# 									<div id="p-personal" role="navigation" class="" aria-labelledby="p-personal-label">
# 						<h3 id="p-personal-label">Personal tools</h3>
# 						<ul>
# 							<li id="pt-anonuserpage">Not logged in</li><li id="pt-anontalk"><a href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]" accesskey="n">Talk</a></li><li id="pt-anoncontribs"><a href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]" accesskey="y">Contributions</a></li><li id="pt-createaccount"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Neville+Hewitt+%28American+football%29" title="You are encouraged to create an account and log in; however, it is not mandatory">Create account</a></li><li id="pt-login"><a href="/w/index.php?title=Special:UserLogin&amp;returnto=Neville+Hewitt+%28American+football%29" title="You're encouraged to log in; however, it's not mandatory. [o]" accesskey="o">Log in</a></li>						</ul>
# 					</div>
# 									<div id="left-navigation">
# 										<div id="p-namespaces" role="navigation" class="vectorTabs" aria-labelledby="p-namespaces-label">
# 						<h3 id="p-namespaces-label">Namespaces</h3>
# 						<ul>
# 															<li  id="ca-nstab-main" class="selected"><span><a href="/wiki/Neville_Hewitt_(American_football)"  title="View the content page [c]" accesskey="c">Article</a></span></li>
# 															<li  id="ca-talk"><span><a href="/wiki/Talk:Neville_Hewitt_(American_football)"  title="Discussion about the content page [t]" accesskey="t" rel="discussion">Talk</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-variants" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-variants-label">
# 												<h3 id="p-variants-label">
# 							<span>Variants</span><a href="#"></a>
# 						</h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 									</div>
# 				<div id="right-navigation">
# 										<div id="p-views" role="navigation" class="vectorTabs" aria-labelledby="p-views-label">
# 						<h3 id="p-views-label">Views</h3>
# 						<ul>
# 															<li id="ca-view" class="selected"><span><a href="/wiki/Neville_Hewitt_(American_football)" >Read</a></span></li>
# 															<li id="ca-edit"><span><a href="/w/index.php?title=Neville_Hewitt_(American_football)&amp;action=edit"  title="Edit this page [e]" accesskey="e">Edit</a></span></li>
# 															<li id="ca-history" class="collapsible"><span><a href="/w/index.php?title=Neville_Hewitt_(American_football)&amp;action=history"  title="Past revisions of this page [h]" accesskey="h">View history</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-cactions" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-cactions-label">
# 						<h3 id="p-cactions-label"><span>More</span><a href="#"></a></h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 										<div id="p-search" role="search">
# 						<h3>
# 							<label for="searchInput">Search</label>
# 						</h3>
#
# 						<form action="/w/index.php" id="searchform">
# 							<div id="simpleSearch">
# 							<input type="search" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" accesskey="f" id="searchInput"/><input type="hidden" value="Special:Search" name="title"/><input type="submit" name="fulltext" value="Search" title="Search Wikipedia for this text" id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/><input type="submit" name="go" value="Go" title="Go to a page with this exact name if it exists" id="searchButton" class="searchButton"/>							</div>
# 						</form>
# 					</div>
# 									</div>
# 			</div>
# 			<div id="mw-panel">
# 				<div id="p-logo" role="banner"><a class="mw-wiki-logo" href="/wiki/Main_Page"  title="Visit the main page"></a></div>
# 						<div class="portal" role="navigation" id='p-navigation' aria-labelledby='p-navigation-label'>
# 			<h3 id='p-navigation-label'>Navigation</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-mainpage-description"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z">Main page</a></li><li id="n-contents"><a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-featuredcontent"><a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a href="/wiki/Special:Random" title="Load a random article [x]" accesskey="x">Random article</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li><li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-interaction' aria-labelledby='p-interaction-label'>
# 			<h3 id='p-interaction-label'>Interaction</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]" accesskey="r">Recent changes</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-tb' aria-labelledby='p-tb-label'>
# 			<h3 id='p-tb-label'>Tools</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="t-whatlinkshere"><a href="/wiki/Special:WhatLinksHere/Neville_Hewitt_(American_football)" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j">What links here</a></li><li id="t-recentchangeslinked"><a href="/wiki/Special:RecentChangesLinked/Neville_Hewitt_(American_football)" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k">Related changes</a></li><li id="t-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u">Upload file</a></li><li id="t-specialpages"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=Neville_Hewitt_(American_football)&amp;oldid=759899379" title="Permanent link to this revision of the page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=Neville_Hewitt_(American_football)&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a href="https://www.wikidata.org/wiki/Q21621474" title="Link to connected data repository item [g]" accesskey="g">Wikidata item</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Neville_Hewitt_%28American_football%29&amp;id=759899379" title="Information on how to cite this page">Cite this page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-coll-print_export' aria-labelledby='p-coll-print_export-label'>
# 			<h3 id='p-coll-print_export-label'>Print/export</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=Neville+Hewitt+%28American+football%29">Create a book</a></li><li id="coll-download-as-rdf2latex"><a href="/w/index.php?title=Special:Book&amp;bookcmd=render_article&amp;arttitle=Neville+Hewitt+%28American+football%29&amp;returnto=Neville+Hewitt+%28American+football%29&amp;oldid=759899379&amp;writer=rdf2latex">Download as PDF</a></li><li id="t-print"><a href="/w/index.php?title=Neville_Hewitt_(American_football)&amp;printable=yes" title="Printable version of this page [p]" accesskey="p">Printable version</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-lang' aria-labelledby='p-lang-label'>
# 			<h3 id='p-lang-label'>Languages</h3>
#
# 			<div class="body">
# 									<ul>
# 											</ul>
# 				<div class='after-portlet after-portlet-lang'><span class="wb-langlinks-add wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Q21621474#sitelinks-wikipedia" title="Add interlanguage links" class="wbc-editpage">Add links</a></span></div>			</div>
# 		</div>
# 				</div>
# 		</div>
# 		<div id="footer" role="contentinfo">
# 							<ul id="footer-info">
# 											<li id="footer-info-lastmod"> This page was last modified on 13 January 2017, at 19:26.</li>
# 											<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License</a><a rel="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//wikimediafoundation.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//wikimediafoundation.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# 									</ul>
# 							<ul id="footer-places">
# 											<li id="footer-places-privacy"><a href="https://wikimediafoundation.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy policy</a></li>
# 											<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# 											<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# 											<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 											<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# 											<li id="footer-places-cookiestatement"><a href="https://wikimediafoundation.org/wiki/Cookie_statement">Cookie statement</a></li>
# 											<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=Neville_Hewitt_(American_football)&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# 									</ul>
# 										<ul id="footer-icons" class="noprint">
# 											<li id="footer-copyrightico">
# 							<a href="https://wikimediafoundation.org/"><img src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a>						</li>
# 											<li id="footer-poweredbyico">
# 							<a href="//www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>						</li>
# 									</ul>
# 						<div style="clear:both"></div>
# 		</div>
# 		<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.224","walltime":"0.272","ppvisitednodes":{"value":2342,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":43722,"limit":2097152},"templateargumentsize":{"value":3719,"limit":2097152},"expansiondepth":{"value":15,"limit":40},"expensivefunctioncount":{"value":0,"limit":500},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  242.459      1 -total"," 71.43%  173.182      1 Template:Infobox_NFL_player"," 70.10%  169.954      5 Template:Infobox"," 16.50%   40.006      1 Template:Miami_Dolphins_roster_navbox"," 15.65%   37.947      1 Template:Team_roster_navbox"," 15.21%   36.883      2 Template:Convinfobox"," 13.85%   33.592      2 Template:NFLPrimaryStyle"," 13.40%   32.488      1 Template:Convinfobox/prisec3"," 12.49%   30.290      2 Template:Convert"," 11.74%   28.459      1 Template:Reflist"]},"scribunto":{"limitreport-timeusage":{"value":"0.086","limit":"10.000"},"limitreport-memusage":{"value":3659164,"limit":52428800}},"cachereport":{"origin":"mw1302","timestamp":"20170303031127","ttl":3600,"transientcontent":true}}});});</script><script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":58,"wgHostname":"mw1242"});});</script>
# 	</body>
# </html>

# %% [markdown]
# #### It appears that the main content is nested inside the div tag with the id content.
#
# ## Reading In The Data

# %%
import concurrent.futures
import time

pool = concurrent.futures.ThreadPoolExecutor(max_workers=4)

def read_data(filename):
    with open(filename) as f:
        data = f.read()
    return data

start = time.time()
filenames = ["wiki/{}".format(f) for f in os.listdir("wiki")]
content = pool.map(read_data, filenames)
content = list(content)

end = time.time()
print(end - start)
articles = [f.replace(".html", "").replace("wiki/", "") for f in filenames]
# Out:
# 0.3742208480834961

# %% [markdown]
# After doing some profiling, it doesn't appear that threading makes a huge difference to performance. It may be because although files are opened, most of the task is offset by the overhead of creating new threads.
#
# ### Remove Extraneous Markup

# %%
from bs4 import BeautifulSoup

def parse_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    return str(soup.find_all("div", id="content")[0])

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
parsed = pool.map(parse_html, content)
parsed = list(parsed)
end = time.time()

print(end - start)
# Out:
# 54.99400591850281

# %%
parsed[0]
# Out:
# '<div class="mw-body" id="content" role="main">\n<a id="top"></a>\n<div id="siteNotice"><!-- CentralNotice --></div>\n<div class="mw-indicators">\n</div>\n<h1 class="firstHeading" id="firstHeading" lang="en">Furubira District, Hokkaido</h1>\n<div class="mw-body-content" id="bodyContent">\n<div id="siteSub">From Wikipedia, the free encyclopedia</div>\n<div id="contentSub"></div>\n<div class="mw-jump" id="jump-to-nav">\n\t\t\t\t\tJump to:\t\t\t\t\t<a href="#mw-head">navigation</a>, \t\t\t\t\t<a href="#p-search">search</a>\n</div>\n<div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><table class="plainlinks metadata ambox ambox-content ambox-Unreferenced" role="presentation">\n<tr>\n<td class="mbox-image">\n<div style="width:52px"><a class="image" href="/wiki/File:Question_book-new.svg"><img alt="" data-file-height="399" data-file-width="512" height="39" src="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/50px-Question_book-new.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/75px-Question_book-new.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/100px-Question_book-new.svg.png 2x" width="50"/></a></div>\n</td>\n<td class="mbox-text"><span class="mbox-text-span">This article <b>does not <a href="/wiki/Wikipedia:Citing_sources" title="Wikipedia:Citing sources">cite</a> any <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">sources</a></b>. <span class="hide-when-compact">Please help <a class="external text" href="//en.wikipedia.org/w/index.php?title=Furubira_District,_Hokkaido&amp;action=edit">improve this article</a> by <a href="/wiki/Help:Introduction_to_referencing_with_Wiki_Markup/1" title="Help:Introduction to referencing with Wiki Markup/1">adding citations to reliable sources</a>. Unsourced material may be challenged and <a href="/wiki/Wikipedia:Verifiability#Burden_of_evidence" title="Wikipedia:Verifiability">removed</a>.</span> <small><i>(December 2009)</i></small> <small class="hide-when-compact"><i>(<a href="/wiki/Help:Maintenance_template_removal" title="Help:Maintenance template removal">Learn how and when to remove this template message</a>)</i></small></span></td>\n</tr>\n</table>\n<div class="thumb tright">\n<div class="thumbinner" style="width:202px;"><a class="image" href="/wiki/File:Furubira_in_Shiribeshi_Subprefecture.gif"><img alt="" class="thumbimage" data-file-height="368" data-file-width="600" height="123" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Furubira_in_Shiribeshi_Subprefecture.gif/200px-Furubira_in_Shiribeshi_Subprefecture.gif" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Furubira_in_Shiribeshi_Subprefecture.gif/300px-Furubira_in_Shiribeshi_Subprefecture.gif 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Furubira_in_Shiribeshi_Subprefecture.gif/400px-Furubira_in_Shiribeshi_Subprefecture.gif 2x" width="200"/></a>\n<div class="thumbcaption">\n<div class="magnify"><a class="internal" href="/wiki/File:Furubira_in_Shiribeshi_Subprefecture.gif" title="Enlarge"></a></div>\nFurubira in Shiribeshi Subprefecture.</div>\n</div>\n</div>\n<p><b>Furubira</b> <span style="font-weight: normal">(<span class="t_nihongo_kanji" lang="ja" xml:lang="ja">古平郡</span><span class="t_nihongo_comma" style="display:none">,</span> <i>Furubira-gun</i><sup class="t_nihongo_help noprint"><a href="/wiki/Help:Installing_Japanese_character_sets" title="Help:Installing Japanese character sets"><span class="t_nihongo_icon" style="color: #00e; font: bold 80% sans-serif; text-decoration: none; padding: 0 .1em;">?</span></a></sup>)</span> is a <a href="/wiki/Districts_of_Japan" title="Districts of Japan">district</a> located in <a href="/wiki/Shiribeshi_Subprefecture" title="Shiribeshi Subprefecture">Shiribeshi Subprefecture</a>, <a href="/wiki/Hokkaido" title="Hokkaido">Hokkaido</a>, <a href="/wiki/Japan" title="Japan">Japan</a>.</p>\n<p>As of 2004, the district has an es ...

# %% [markdown]
# This operation is quite slow and CPU-intensive. It looks like using as many processes are there are available processors speeds things up.
#
# ### Finding Common Tags¶

# %%
from bs4 import BeautifulSoup

def count_tags(html):
    soup = BeautifulSoup(html, 'html.parser')
    tags = {}
    for tag in soup.find_all():
        if tag.name not in tags:
            tags[tag.name] = 0
        tags[tag.name] += 1
    return tags

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
tags = pool.map(count_tags, parsed)
tags = list(tags)

tag_counts = {}
for tag in tags:
    for k,v in tag.items():
        if k not in tag_counts:
            tag_counts[k] = 0
        tag_counts[k] += v
end = time.time()

print(end - start)
tag_counts
# Out:
# 27.503178119659424
# {'a': 161065,
#  'abbr': 3665,
#  'annotation': 2,
#  'area': 39,
#  'audio': 2,
#  'b': 14455,
#  'bdi': 4,
#  'big': 75,
#  'blockquote': 58,
#  'br': 4986,
#  'caption': 200,
#  'center': 64,
#  'cite': 3563,
#  'code': 108,
#  'dd': 1376,
#  'del': 2,
#  'div': 28581,
#  'dl': 457,
#  'dt': 334,
#  'font': 40,
#  'h1': 999,
#  'h2': 4045,
#  'h3': 777,
#  'h4': 117,
#  'h5': 4,
#  'h6': 1,
#  'hr': 51,
#  'i': 18246,
#  'img': 6701,
#  'li': 85779,
#  'map': 2,
#  'math': 2,
#  'mo': 2,
#  'mrow': 2,
#  'mstyle': 2,
#  'noscript': 999,
#  'ol': 858,
#  'p': 7998,
#  'pre': 1,
#  'q': 76,
#  'rb': 16,
#  'rp': 32,
#  'rt': 16,
#  'ruby': 16,
#  's': 10,
#  'samp': 2,
#  'semantics': 2,
#  'small': 3272,
#  'source': 2,
#  'span': 67350,
#  'strong': 599,
#  'sub': 151,
#  'sup': 11157,
#  'table': 4010,
#  'td': 57673,
#  'th': 14472,
#  'tr': 27300,
#  'u': 51,
#  'ul': 10972,
#  'wbr': 85}

# %% [markdown]
# Based on our findings, it looks like there are quite a few td, a, li, and span tags. This indicates that articles tend to have lots of links, along with lists and tables. Links are the most numerous tag, which indicates how interconnected articles on Wikipedia are.
#
# ## Finding Common Words

# %%
from bs4 import BeautifulSoup
from collections import Counter
import re

def count_words(html):
    soup = BeautifulSoup(html, 'html.parser')
    words = {}
    text = soup.get_text()
    text = re.sub("\W+", " ", text.lower())
    words = text.split(" ")
    words = [w for w in words if len(w) >= 5]
    return Counter(words).most_common(10)

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
words = pool.map(count_words, parsed)
words = list(words)

word_counts = {}
for wc in words:
    for word, count in wc:
        if word not in word_counts:
            word_counts[word] = 0
        word_counts[word] += 1
end = time.time()

print(end - start)
word_counts
# Out:
# 27.337949991226196
# {'switzerland': 5,
#  'symptoms': 1,
#  'goiás': 1,
#  'gewächshaus': 1,
#  '25744': 1,
#  'golden': 1,
#  'fruit': 1,
#  'mohammad': 3,
#  'spectra': 1,
#  'dupuis': 1,
#  '78278': 1,
#  'pereira': 1,
#  'gorge': 1,
#  'figure': 2,
#  'amman': 1,
#  'okoye': 1,
#  'baronet': 1,
#  'bratislava': 1,
#  'hoffbauer': 1,
#  'administrative': 1,
#  'nguyên': 1,
#  'opportunities': 1,
#  'stars': 1,
#  'dancer': 1,
#  'cruisers': 1,
#  'rights': 2,
#  'hartford': 1,
#  'protocol': 1,
#  'councillors': 1,
#  'grichka': 1,
#  'psychic': 1,
#  'valley': 7,
#  'borders': 1,
#  'partisan': 1,
#  'chickens': 1,
#  'henry': 1,
#  'farvandsvæsenet': 1,
#  'skaalum': 1,
#  'listing': 1,
#  'khaganate': 1,
#  'alberta': 2,
#  'bahrain': 1,
#  'cities': 6,
#  'anime': 1,
#  'burbridge': 1,
#  'harlekijn': 1,
#  'miguel': 1,
#  'fischtown': 1,
#  'found': 1,
#  'vivian': 1,
#  'thompson': 1,
#  'breakthrough': 1,
#  'möschler': 1,
#  '23861': 1,
#  'gonzález': 1,
#  'veturi': 1,
#  'australia': 11,
#  'media': 4,
#  'howard': 2,
#  'garmsiri': 1,
#  'cartel': 1,
#  'sowme': 1,
#  'primitives': 1,
#  'calyptraeidae': 1,
#  'zgornji': 1,
#  'laboratoire': 1,
#  'colonel': 1,
#  'inertia': 1,
#  'native': 4,
#  'vesle': 2,
#  'bicolor': 1,
#  'preceded': 3,
#  'codex': 1,
#  'hasbro': 1,
#  'reverse': 2,
#  'merchant': 1,
#  'blight': 1,
#  'markus': 1,
#  'scotia': 1,
#  'andersson': 1,
#  'kumar': 1,
#  'venus': 2,
#  'powys': 1,
#  'eggerberg': 1,
#  'swimming': 1,
#  'lunar': 1,
#  'theory': 3,
#  'baxter': 1,
#  'panhandle': 1,
#  'medical': 4,
#  'brigade': 1,
#  'vivet': 1,
#  'fleur': 1,
#  'hemiargyropsis': 1,
#  'phycita': 1,
#  'harvey': 2,
#  'champions': 1,
#  'tygři': 1,
#  'hackensaw': 1,
#  'acrolophidae': 1,
#  'reddy': 1,
#  'stores': 1,
#  'tunnel': 1,
#  'strayhorn': 1,
#  'perigee': 1,
#  'albert': 1,
#  'affiliations': 1,
#  'period': 1,
#  'arcade': 1,
#  'indonesia': 1,
#  'spoon': 1,
#  'clinic': 1,
#  'clarification': 1,
#  'malabsorption': 1,
#  'nathan': 1,
#  'aragón': 1,
#  'sculls': 1,
#  'devarampally': 1,
#  'diplacus': 1,
#  'santa': 2,
#  'fulminate': 1,
#  'minor': 2,
#  'comune': 1,
#  'caesar': 1,
#  'diego': 2,
#  'failing': 1,
#  'mount': 5,
#  'plzeň': 2,
#  'steel': 2,
#  'dhayalan': 1,
#  'madrid': 2,
#  'grahamstown': 1,
#  'federal': 2,
#  'theater': 3,
#  'rouen': 1,
#  'plant': 7,
#  'common': 2,
#  'award': 6,
#  'john_whewell': 1,
#  'tamil': 6,
#  'singamperumal': 1,
#  'bosnia': 1,
#  'dakar': 1,
#  'stratigraphic': 1,
#  'physical': 1,
#  'oligocentris': 1,
#  'schneider': 1,
#  'bradley': 1,
#  'valgus': 1,
#  'tournaments': 1,
#  '96028': 1,
#  'edmonton': 2,
#  '59194': 1,
#  'submarines': 2,
#  'adams': 1,
#  'forbidden': 1,
#  'magnetic': 1,
#  'circle': 1,
#  'forward': 3,
#  'tlélat': 1,
#  'section': 4,
#  'unsourced': 4,
#  'defunct': 3,
#  'fleabane': 1,
#  'mcadams': 1,
#  'democratic': 3,
#  'polytaenia': 1,
#  'egypt': 1,
#  'farbridge': 1,
#  'gamma': 1,
#  'tillandsia': 1,
#  'available': 1,
#  'cygany': 1,
#  'juist': 1,
#  'extinct': 1,
#  'vancouver': 3,
#  'tehran': 2,
#  'communes': 3,
#  'devil': 1,
#  'interconnect': 1,
#  'baltimore': 3,
#  'agreement': 2,
#  'sierra': 4,
#  'nobuhiko': 1,
#  'andhra': 1,
#  'wilkes': 1,
#  'shekhar': 1,
#  'russell': 3,
#  'huddersfield': 1,
#  'sprue': 1,
#  'paralysis': 1,
#  'chocolate': 1,
#  'constitution': 1,
#  'manchester': 1,
#  'figaro': 1,
#  'england': 10,
#  'energy': 1,
#  'composer': 1,
#  'under': 2,
#  'tapatío': 1,
#  'stela': 1,
#  'tetrapods': 1,
#  'liberty': 2,
#  'purposes': 1,
#  'vessel': 2,
#  'eliteprospects': 1,
#  'dalian': 1,
#  'constable': 1,
#  'frederiksø': 1,
#  'nagariya': 1,
#  'restaurant': 1,
#  'patella': 1,
#  'territorial': 1,
#  'ragnar': 1,
#  'corinth': 1,
#  'manufacturer': 1,
#  'mykines': 1,
#  'saskatchewan': 1,
#  'friends': 1,
#  'baggy': 1,
#  'supermoons': 1,
#  'yeats': 1,
#  'cotterell': 1,
#  'examine': 1,
#  'event': 6,
#  'pyrochta': 1,
#  'cantonment': 1,
#  'vikings': 1,
#  'blues': 5,
#  'soviet': 4,
#  'parrots': 1,
#  'county': 61,
#  'banate': 1,
#  'promises': 1,
#  'exploratorium': 1,
#  'liechtenstein': 1,
#  'republic': 9,
#  'skatepark': 1,
#  'vitaly': 1,
#  'quadruple': 1,
#  'klaus': 1,
#  'noise': 1,
#  'lelyveld': 1,
#  'content': 2,
#  'dawson': 1,
#  'oakley': 1,
#  'erzgebirgskreis': 1,
#  'transit': 1,
#  'brograve': 1,
#  'bozorg': 1,
#  'kinda': 1,
#  'scoreboards': 1,
#  'shahid': 2,
#  'prime': 2,
#  'havnar': 1,
#  'muslims': 1,
#  'southern': 4,
#  'issue': 1,
#  'cluster': 1,
#  'forstenried': 1,
#  'luciano': 1,
#  'comandante': 1,
#  'newspaper': 1,
#  'helen': 2,
#  'gorrie': 1,
#  'makushita': 1,
#  'taipa': 1,
#  'puchov': 1,
#  'aperiens': 1,
#  'gornja': 1,
#  'space': 4,
#  'electoral': 1,
#  'foundation': 6,
#  'audio': 1,
#  'slovenia': 1,
#  'guaricana': 1,
#  'shivaji': 1,
#  'nagashi': 1,
#  'allee': 1,
#  'issues': 1,
#  'lloyd': 1,
#  'alabama': 3,
#  'cruze': 1,
#  'sacks': 1,
#  'association': 2,
#  'newfoundland': 2,
#  'arčikauskas': 1,
#  'waldoboro': 1,
#  'beneficiaries': 1,
#  'appearances': 1,
#  'balázs': 1,
#  'manufacturing': 1,
#  'marriage': 1,
#  'development': 9,
#  'turnout': 1,
#  'diphilus': 1,
#  'motorsport': 1,
#  'melling': 1,
#  'zlatoust': 1,
#  'soyuz': 1,
#  'notes': 2,
#  '45x90': 1,
#  'painted': 1,
#  'sankaradi': 1,
#  'wellington': 2,
#  'banking': 1,
#  'infected': 2,
#  'pseudoluteata': 1,
#  'spradlin': 1,
#  'kurtzman': 1,
#  '55056': 1,
#  'sexism': 1,
#  'argentina': 4,
#  'systematic': 1,
#  'bangladesh': 1,
#  'musculoskeletal': 1,
#  'beyond': 2,
#  'crepidula': 1,
#  'young': 4,
#  'discretionary': 1,
#  'second': 7,
#  'ocean': 1,
#  'distributor': 1,
#  'chiddingstone': 1,
#  'machine': 1,
#  'jules': 1,
#  'bungarotoxin': 1,
#  'école': 1,
#  'english': 11,
#  'wedding': 2,
#  'khaleh': 1,
#  'guests': 1,
#  'sebastião': 1,
#  'enghave': 1,
#  'hvalba': 1,
#  'quetzaltenango': 1,
#  'nagar': 2,
#  'mangeshkar': 2,
#  'indigenous': 1,
#  'meneng': 1,
#  'operation': 2,
#  'elizabeth': 2,
#  'krishna': 1,
#  'coole': 1,
#  'teskey': 1,
#  'promising': 1,
#  'mollusca': 1,
#  'cricketer': 2,
#  'maneswar': 1,
#  'symeon': 1,
#  'kevoo': 1,
#  'legal': 2,
#  'litera': 1,
#  'spider': 1,
#  'teiji': 1,
#  'filip': 1,
#  'taluk': 1,
#  'blakley': 1,
#  'singles': 9,
#  'leningrad': 1,
#  'boehringer': 1,
#  'berkshire': 1,
#  'posht': 1,
#  'pampanga': 1,
#  'clare': 1,
#  '2017all': 2,
#  'wickets': 2,
#  'messages': 1,
#  'pentium': 1,
#  'biological': 1,
#  'lisewo': 1,
#  'corporations': 1,
#  'tephritidae': 1,
#  'história': 1,
#  'referendums': 2,
#  'chhaparband': 1,
#  'curtiss': 1,
#  'cervia': 1,
#  'golabkhvaran': 1,
#  'spilomelinae': 1,
#  'ogham': 1,
#  'functoid': 1,
#  'uzbekistan': 1,
#  'brooks': 1,
#  'lillard': 1,
#  'clade': 5,
#  'conte': 1,
#  'nematodes': 1,
#  'wilbraham': 1,
#  'jonas': 1,
#  'references': 13,
#  'bunting': 1,
#  'kailas': 1,
#  'ayish': 1,
#  'athletic': 2,
#  'iqbal': 1,
#  'fureai': 1,
#  '39833': 1,
#  'burkart': 1,
#  'affiliated': 1,
#  'patricia': 1,
#  'konstantin': 1,
#  'actressesbrazilian': 1,
#  'exhibitions': 1,
#  'jadraque': 1,
#  'similis': 1,
#  'ofcom': 1,
#  'dortmund': 1,
#  'tyson': 1,
#  'monster': 1,
#  'wangerooge': 1,
#  'knowledge': 1,
#  'alvarez': 1,
#  'blogging': 1,
#  'united': 48,
#  'drugs': 1,
#  'granada': 1,
#  'murder': 2,
#  'religion': 2,
#  'party': 17,
#  'maron': 1,
#  'province': 14,
#  'destroyed': 1,
#  'wilson': 1,
#  'refinement': 1,
#  'indians': 2,
#  'rials': 1,
#  'fritz': 1,
#  'vosta': 1,
#  'christopher': 1,
#  'resolutions': 2,
#  'wilhelm': 1,
#  'rosemann': 1,
#  'indicated': 1,
#  'surface': 2,
#  '59611': 1,
#  'kushiro': 1,
#  'night': 2,
#  'laboratory': 1,
#  'lubowicz': 1,
#  'nejat': 1,
#  '018aa1d0b1e2': 1,
#  'suicide': 1,
#  'opera': 1,
#  'communist': 3,
#  'folios': 1,
#  'barcelona': 1,
#  'tuscaloosa': 1,
#  'british': 18,
#  'mccallum': 1,
#  'ladanyi': 1,
#  'pounder': 1,
#  'sudanese': 1,
#  'puebla': 1,
#  'isontius': 1,
#  'animal': 2,
#  'renault': 2,
#  'admira': 1,
#  'structures': 1,
#  'airlines': 2,
#  'ansari': 1,
#  'plaza': 1,
#  'entitled': 1,
#  'russia': 1,
#  'around': 1,
#  'puzzle': 1,
#  'chestnuts': 1,
#  'aboriginal': 1,
#  'uruguay': 1,
#  'chadian': 1,
#  'nauru': 1,
#  'lesins': 1,
#  'inches': 1,
#  'design': 7,
#  'jezebel': 1,
#  'falcon': 1,
#  '43417': 1,
#  'vitruvius': 1,
#  'glasgow': 1,
#  'lover': 1,
#  'maharaj': 1,
#  'shirley': 1,
#  'houston': 1,
#  'constituency': 2,
#  'videos': 1,
#  'showdown': 1,
#  'yemen': 1,
#  'bureau': 1,
#  'jotedar': 1,
#  'rules': 2,
#  'veteran': 1,
#  'abstraction': 1,
#  'sydney': 3,
#  'order': 4,
#  'syndrome': 2,
#  'taggen': 1,
#  'ministers': 1,
#  'durham': 2,
#  'zombee': 1,
#  'mandal': 1,
#  'missouri': 3,
#  'championships': 9,
#  '76833': 1,
#  'sauces': 1,
#  'sweden': 2,
#  'horeca': 1,
#  'derived': 1,
#  'buildings': 2,
#  'bifidocarpus': 1,
#  'portland': 3,
#  'berzeliustinden': 1,
#  'needed': 2,
#  'systems': 3,
#  'tropical': 2,
#  'industry': 1,
#  'braga': 1,
#  'wetangula': 1,
#  'bluegrass': 1,
#  'advisers': 1,
#  '60306': 1,
#  'pants': 1,
#  'visitors': 1,
#  'liver': 1,
#  'richmond': 1,
#  'olivaceus': 1,
#  'coenaculum': 1,
#  'economics': 1,
#  'ptprs': 1,
#  'sarichioi': 1,
#  'willamette': 1,
#  'kunwar': 1,
#  'denticulata': 1,
#  'romagna': 1,
#  'millennium': 1,
#  'nationale': 2,
#  'works': 2,
#  'hydroxides': 1,
#  'pastime': 1,
#  'preapicemaculata': 1,
#  'stephens': 1,
#  'towards': 1,
#  'gorgopis': 1,
#  'crewe': 1,
#  'casimcea': 1,
#  '69889': 1,
#  'austin': 2,
#  'dakota': 2,
#  'desai': 1,
#  'antioquia': 1,
#  'rowing': 3,
#  'kawczynski': 1,
#  'diocese': 2,
#  'restoration': 1,
#  'morales': 1,
#  'stratford': 1,
#  'godfather': 1,
#  'yarkand': 1,
#  'gustavsson': 1,
#  '10000': 1,
#  'vanuatu': 1,
#  'quảng': 1,
#  'boadicea': 1,
#  'chx10': 1,
#  'autism': 1,
#  'deformity': 1,
#  'tungsten': 1,
#  'newgate': 1,
#  'matriculation': 1,
#  'hepialidae': 1,
#  'inning': 1,
#  'wilstermann': 1,
#  'rostock': 1,
#  'bulbophyllum': 1,
#  'erigeron': 1,
#  'winter': 7,
#  'front': 3,
#  'review': 8,
#  'caffè': 1,
#  'fellow': 1,
#  'institution': 1,
#  'harrison': 2,
#  'información': 1,
#  'referendum': 2,
#  'playa': 1,
#  'kingdom': 5,
#  'database': 3,
#  'heath': 1,
#  'biscuit': 1,
#  'pergamos': 1,
#  'bourbon': 1,
#  'vijayakanth': 1,
#  'selling': 1,
#  'windsor': 1,
#  'burton': 1,
#  'waterfront': 1,
#  'coaches': 1,
#  'champagne': 2,
#  'lines': 2,
#  'fifth': 1,
#  'shabbir': 1,
#  'clive': 1,
#  'general': 18,
#  'parkinson': 1,
#  'hoghiz': 1,
#  'sibling': 1,
#  'romania': 4,
#  'exeter': 2,
#  'kfarhata': 1,
#  'brendan': 1,
#  'eisenhower': 1,
#  'colombia': 3,
#  'arabia': 1,
#  'which': 32,
#  'unranked': 10,
#  'audacity': 1,
#  'remove': 8,
#  'palestinian': 2,
#  'intending': 2,
#  'nellie': 1,
#  'register': 14,
#  'katie': 1,
#  'qualified': 1,
#  'creative': 1,
#  'boutique': 1,
#  'niigata': 2,
#  'lalden': 1,
#  'bombardment': 1,
#  'sprint': 1,
#  'swiss': 6,
#  'guide': 2,
#  'biegeleben': 1,
#  'first': 19,
#  'deciusalis': 1,
#  'house': 12,
#  'freedoms': 1,
#  'hydrogen': 1,
#  'silveira': 1,
#  'episode': 3,
#  'kingdoms': 1,
#  'leksikon': 1,
#  'macroglossum': 1,
#  'dolls': 1,
#  'david': 9,
#  'keshav': 1,
#  'snails': 1,
#  'williams': 5,
#  'chips': 1,
#  'semjan': 1,
#  'pinzón': 1,
#  'creek': 7,
#  'expanding': 11,
#  'haiku': 1,
#  'uloom': 1,
#  'segments': 1,
#  'analysis': 2,
#  'vasas': 1,
#  'siege': 1,
#  'unwin': 1,
#  'qalat': 1,
#  'quarrie': 1,
#  'bibiana': 1,
#  'tennis': 2,
#  'clásico': 1,
#  'dresden': 2,
#  'julien': 1,
#  'kings': 2,
#  'montana': 3,
#  'skaggs': 1,
#  'shoreyjeh': 1,
#  'since': 2,
#  'geojoey': 1,
#  'peninsula': 1,
#  'defender': 1,
#  'malay': 1,
#  'scotland': 3,
#  'antarctic': 1,
#  'cyclohexane': 1,
#  'aggarwala': 1,
#  'gurab': 1,
#  'osella': 1,
#  'sunita': 1,
#  'chico': 1,
#  'project': 3,
#  'tales': 1,
#  'diamond': 1,
#  'moto2': 1,
#  'morten': 1,
#  'générale': 1,
#  'independent': 2,
#  'confederate': 1,
#  'state': 28,
#  'victor': 1,
#  'programs': 2,
#  'cosenza': 1,
#  'philosophy': 2,
#  'great': 5,
#  'species': 66,
#  'eudonia': 1,
#  'bears': 1,
#  'storyboard': 1,
#  'hydroxide': 1,
#  'sickmen': 1,
#  'jeremy': 1,
#  'mcsherry': 1,
#  'american': 29,
#  'heinz': 1,
#  'moshe': 1,
#  'people': 9,
#  'amateur': 1,
#  'chapel': 2,
#  'horace': 2,
#  'giuseppe': 1,
#  'notability': 3,
#  'thailand': 1,
#  'bulgarian': 3,
#  'homeobox': 1,
#  'mexico': 2,
#  'vincent': 1,
#  'management': 4,
#  'tachinidae': 1,
#  'chestnut': 1,
#  'dinamo': 1,
#  'odder': 1,
#  'congregation': 1,
#  'cathedral': 2,
#  'became': 2,
#  'pixley': 1,
#  'indicate': 1,
#  'murex': 1,
#  'brooke': 2,
#  '840516': 1,
#  'trøndelag': 2,
#  'boutros': 1,
#  'garuh': 1,
#  'pribyl': 1,
#  'nicotinic': 1,
#  'messianic': 1,
#  'yankalilla': 1,
#  'simone': 1,
#  'tolombeh': 1,
#  'major': 2,
#  'welfare': 2,
#  'acoustic': 2,
#  'felderman': 1,
#  'names': 11,
#  'rezvanshahr': 1,
#  'bomfunk': 1,
#  'margherita': 1,
#  'solanum': 1,
#  'draft': 1,
#  'motion': 1,
#  'kentucky': 3,
#  'powell': 1,
#  'diakonoff': 1,
#  'incorporating': 2,
#  'accessed': 4,
#  'guitars': 1,
#  'physics': 2,
#  'ellington': 1,
#  'enamul': 1,
#  'antagonists': 1,
#  'resistance': 1,
#  'waldau': 1,
#  'return': 2,
#  'trophy': 3,
#  'hancock': 1,
#  'translation': 4,
#  'florida': 3,
#  'innovation': 2,
#  'kistenuten': 1,
#  'watershields': 1,
#  'planet': 1,
#  'collinlab': 1,
#  'expatriate': 1,
#  'chhatrapati': 1,
#  'awani': 1,
#  'message': 2,
#  'cryptographic': 1,
#  'appointed': 1,
#  'gentleman': 1,
#  'boone': 1,
#  'athens': 1,
#  'henrique': 2,
#  'byron': 1,
#  'cherry': 2,
#  'vinci': 1,
#  'pipefish': 1,
#  'farmeshkhan': 1,
#  'airplay': 1,
#  'genes': 1,
#  'countertenor': 1,
#  'auditor': 1,
#  'tatar': 1,
#  'sextacta': 1,
#  'charlton': 1,
#  'constance': 1,
#  'eardley': 1,
#  'kansas': 4,
#  'dorsal': 1,
#  'pushkar': 1,
#  'dualistic': 1,
#  'sequence': 2,
#  'beirut': 2,
#  'octubre': 1,
#  'flanders': 1,
#  'communications': 1,
#  'frescoes': 1,
#  'almanack': 1,
#  'revold': 1,
#  'erceg': 1,
#  'brien': 1,
#  'driver': 1,
#  'lierne': 1,
#  'little': 1,
#  'wimberley': 1,
#  'incumbent': 1,
#  'knoxville': 2,
#  'prisons': 2,
#  'geography': 5,
#  'turkic': 1,
#  'edelen': 1,
#  'torreggiani': 1,
#  'jeffrey': 2,
#  'parks': 1,
#  'buday': 1,
#  'larvicide': 1,
#  'robertson': 1,
#  'gaddafi': 1,
#  'goreau': 1,
#  'challenger': 2,
#  'closest': 1,
#  'arkansas': 4,
#  'coups': 1,
#  'shown': 1,
#  'forstenrieder': 1,
#  'govindarajan': 1,
#  'khani': 1,
#  'spiders': 1,
#  'ascomycota': 1,
#  'examiner': 1,
#  'lipnica': 1,
#  'expeditionary': 1,
#  'killings': 1,
#  'joint': 2,
#  'luvvie': 1,
#  'cordray': 1,
#  '125cc': 1,
#  'phonon': 1,
#  'abruzzo': 1,
#  'footballer': 1,
#  'unclear': 1,
#  'galápagos': 1,
#  'georgian': 2,
#  'institut': 1,
#  'special': 1,
#  'kamenogorsk': 1,
#  'pokal': 1,
#  '92528': 1,
#  'birmingham': 1,
#  'mortes': 1,
#  'anderson': 1,
#  'edward': 1,
#  'termed': 1,
#  'company': 12,
#  'agonists': 2,
#  'alzheimer': 1,
#  'gipson': 1,
#  'brazil': 2,
#  'supermoon': 1,
#  'alexandra': 1,
#  'triathlon': 1,
#  'poland': 6,
#  'joseph': 1,
#  'sphaerocarpos': 1,
#  'currency': 2,
#  'registry': 1,
#  'córdoba': 1,
#  'progress': 1,
#  'württemberg': 1,
#  'irihirose': 1,
#  'economic': 2,
#  'oldid': 2,
#  'farms': 1,
#  'mattel': 1,
#  'stephen': 1,
#  'montreal': 3,
#  'prostylos': 1,
#  'legend': 1,
#  'filmsamerican': 1,
#  'bruses': 1,
#  'demography': 1,
#  'parliament': 11,
#  'monroe': 1,
#  'alien': 1,
#  'hormone': 1,
#  'pudica': 1,
#  'portable': 1,
#  'belvedere': 2,
#  'panna': 1,
#  'technical': 2,
#  'mouse': 3,
#  'peninsular': 1,
#  'zemmour': 1,
#  'zonata': 1,
#  'schauspielhaus': 1,
#  'cross': 1,
#  'kendalia': 1,
#  'kolhapur': 1,
#  'leone': 1,
#  'holbæk': 1,
#  'chinukulu': 1,
#  '08444': 1,
#  '48056': 1,
#  'emulations': 1,
#  'khikhani': 1,
#  'dictionary': 1,
#  'bonus': 1,
#  'macho': 1,
#  'letters': 1,
#  'panchamrutham': 1,
#  'nadeshiko': 1,
#  'wilcox': 1,
#  'freiherr': 1,
#  'epirus': 1,
#  'structure': 9,
#  'quickpath': 1,
#  'gardner': 1,
#  'wehrmacht': 1,
#  'reuten': 1,
#  'kendall': 1,
#  'paintersrussian': 1,
#  'naxalbari': 1,
#  'brewery': 1,
#  'capitol': 1,
#  'beers': 1,
#  'mills': 1,
#  'oxidase': 1,
#  'solydxk': 1,
#  'naganur': 1,
#  'chester': 2,
#  'santos': 2,
#  'chemin': 1,
#  'deadline': 1,
#  'vallis': 1,
#  'savory': 1,
#  'chromosome': 2,
#  'armenian': 1,
#  'gelechiidae': 1,
#  'participations': 1,
#  'chhatrasal': 1,
#  'combined': 1,
#  'eighty': 1,
#  'canonical': 1,
#  'galatasaray': 1,
#  'cybernetics': 1,
#  'dolphins': 1,
#  'préliminaires': 1,
#  'surnameshidden': 1,
#  'belgian': 2,
#  'unpaid': 1,
#  'pioneers': 1,
#  'huang': 1,
#  'groves': 1,
#  'saddleback': 1,
#  'writing': 3,
#  'female': 2,
#  'heiko': 1,
#  'shahu': 1,
#  'fusinus': 1,
#  'prisoners': 1,
#  'peptides': 1,
#  'sluggers': 1,
#  'brother': 2,
#  'reform': 1,
#  'transport': 2,
#  'perez': 1,
#  'renal': 1,
#  'watches': 1,
#  'server': 1,
#  'school': 34,
#  'tropische': 1,
#  'wayne': 1,
#  'federation': 1,
#  'foster': 2,
#  'pennsylvania': 1,
#  'lattice': 1,
#  'cheshire': 1,
#  'sahanpur': 1,
#  'fischli': 1,
#  'architecture': 1,
#  'treaty': 2,
#  'capital': 1,
#  'medien': 2,
#  'kavar': 1,
#  'arcadio': 1,
#  'aragonese': 1,
#  'stations': 13,
#  'japan': 9,
#  'latin': 5,
#  'precorrin': 1,
#  ...}

# %% [markdown]
# Only selecting the top 10 words from each article speeds up performance quite a bit.
